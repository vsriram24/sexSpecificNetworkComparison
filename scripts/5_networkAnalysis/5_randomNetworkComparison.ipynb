# %% [markdown]
# ## Import statements

# %%
# Import required packages
import pandas as pd
import numpy as np
import networkx as nx
import random
from scipy.stats import ttest_1samp
from networkx.algorithms.community import modularity
import community.community_louvain as community_louvain
from itertools import combinations
import statistics

random.seed(123)

# %% [markdown]
# ## Function definitions

# %%
# Function to generate random networks
def generate_random_weighted_network_with_expected_degree(degree_seq, original_weights, original_node_labels):
    while True:
        # Generate a random network with the expected degree distribution
        randomized_graph = nx.expected_degree_graph(degree_seq, selfloops=False)

        if nx.is_connected(randomized_graph):
            # Reassign original node labels
            mapping = {old_label: new_label for old_label, new_label in zip(randomized_graph.nodes(), original_node_labels)}
            randomized_graph = nx.relabel_nodes(randomized_graph, mapping)

            # Reassign weights randomly to the edges
            randomized_weights = random.sample(original_weights, len(original_weights))
            for (u, v), weight in zip(randomized_graph.edges(), randomized_weights):
                randomized_graph[u][v]["weight"] = weight
            
            return randomized_graph

# %%
# Function to compute various metrics for a graph
def compute_graph_metrics(graph, node_category_dict):
    metrics = {}
    
    # Average degree
    metrics["average_degree"] = sum(dict(graph.degree()).values()) / len(graph)
    
    # Average weighted degree
    metrics["average_weighted_degree"] = sum(dict(graph.degree(weight="weight")).values()) / len(graph)

    # Average path length (only if graph is connected)
    if nx.is_connected(graph):
        metrics["average_path_length"] = nx.average_shortest_path_length(graph)
        metrics["network_diameter"] = nx.diameter(graph)
        
    # Graph density
    metrics["graph_density"] = nx.density(graph)
    
    # Modularity (using Louvain method)
    partition = community_louvain.best_partition(graph)
    communities = {}
    for node, comm_id in partition.items():
        communities.setdefault(comm_id, set()).add(node)
    modularity_communities = list(communities.values())
    metrics["modularity"] = modularity(graph, modularity_communities)
    
    # Average clustering coefficient
    metrics["average_clustering"] = nx.average_clustering(graph)

    # Percent of cross-category edges
    num_cc_edges = 0
    for edge in graph.edges:
        first_node = edge[0]
        second_node = edge[1]
        first_category = node_category_dict[first_node]
        second_category = node_category_dict[second_node]
        if first_category != second_category:
            num_cc_edges += 1
    metrics["percent_cross_category_edges"] = num_cc_edges/len(graph.edges)*100

    return metrics

# %%
# Function to perform a t-test; is the difference between the male and female network
#  significantly different from differences in a random population?
def perform_statistical_analysis(original_value_f, original_value_m, random_values):
    original_difference = original_value_f - original_value_m

    random_differences = [rv1 - rv2 for rv1, rv2 in combinations(random_values, 2)]

    t_stat, p_value = ttest_1samp(random_differences, original_difference)
    
    return {
        "original_difference": original_difference,
        "mean_random_difference": np.mean(random_differences),
        "std_random_difference": np.std(random_differences),
        "t_stat": t_stat,
        "p_value": p_value,
    }

# %% [markdown]
# ## Perform analysis

# %%
# Node map
node_categories_path = "/Users/vsriram/Desktop/GxS/ddnComp_personalComputer/traitDescription_diseaseCategories.csv"
node_categories = pd.read_csv(node_categories_path, sep=",")[['Id', 'Disease Category']].set_index('Id')['Disease Category'].to_dict()

# %%
# Import male and female networks
f_file_path = "/Users/vsriram/Desktop/GxS/ddnComp_personalComputer/ddnsForDDNComp/ssDDNneg4_femaleBlock_edgeMap.tsv"
f_edges_df = pd.read_csv(f_file_path, sep="\t").iloc[:, :3]
f_edges_df['Weight'] = pd.to_numeric(f_edges_df['Weight'], errors='coerce')

m_file_path = "/Users/vsriram/Desktop/GxS/ddnComp_personalComputer/ddnsForDDNComp/ssDDNneg4_maleBlock_edgeMap.tsv"
m_edges_df = pd.read_csv(m_file_path, sep="\t").iloc[:, :3]
m_edges_df['Weight'] = pd.to_numeric(m_edges_df['Weight'], errors='coerce')

# %%
f_node_labels = list(set(f_edges_df['Source']).union(set(f_edges_df['Target'])))
m_node_labels = list(set(m_edges_df['Source']).union(set(m_edges_df['Target'])))

# %%
# Create the original graphs
G_f = nx.Graph()
G_f.add_weighted_edges_from(f_edges_df.values)

G_m = nx.Graph()
G_m.add_weighted_edges_from(m_edges_df.values)

# %%
# Compute the degree sequences
f_degree_sequence = [d for n, d in G_f.degree()]
m_degree_sequence = [d for n, d in G_m.degree()]

# %%
# Extract edge weights
f_original_weights = [d["weight"] for _, _, d in G_f.edges(data=True)]
m_original_weights = [d["weight"] for _, _, d in G_m.edges(data=True)]

# %%
# Generate 50 random networks per sex
num_random_networks = 1000

f_random_networks = [
    generate_random_weighted_network_with_expected_degree(f_degree_sequence, f_original_weights, f_node_labels)
    for _ in range(num_random_networks)
]

# %%
m_random_networks = [
    generate_random_weighted_network_with_expected_degree(m_degree_sequence, m_original_weights, m_node_labels)
    for _ in range(num_random_networks)
]

random_networks = f_random_networks + m_random_networks

# %%
# Compute metrics for the original graphs
f_original_metrics = compute_graph_metrics(G_f, node_categories)
m_original_metrics = compute_graph_metrics(G_m, node_categories)

# %%
# Compute metrics for each random network
random_metrics = [compute_graph_metrics(net, node_categories) for net in random_networks]

# %%
# Perform t-tests for each metric
results = {}
for metric in f_original_metrics.keys():
    random_values = [rm[metric] for rm in random_metrics]
    results[metric] = perform_statistical_analysis(f_original_metrics[metric], m_original_metrics[metric], random_values)

# %%
random_metrics
# Out:
# [{'average_degree': 12.718446601941748,
#   'average_weighted_degree': 1372.6019417475727,
#   'average_path_length': 2.187321530553969,
#   'network_diameter': 4,
#   'graph_density': 0.12469065296021321,
#   'modularity': 0.6738536361800113,
#   'average_clustering': 0.4071671728122718,
#   'percent_cross_category_edges': 92.67175572519083},
#  {'average_degree': 12.79611650485437,
#   'average_weighted_degree': 1333.2427184466019,
#   'average_path_length': 2.2381496287835523,
#   'network_diameter': 5,
#   'graph_density': 0.12545212259661145,
#   'modularity': 0.6383892775291848,
#   'average_clustering': 0.4132179413200597,
#   'percent_cross_category_edges': 93.17147192716236},
#  {'average_degree': 11.728155339805825,
#   'average_weighted_degree': 1244.2718446601941,
#   'average_path_length': 2.286502950694841,
#   'network_diameter': 5,
#   'graph_density': 0.11498191509613555,
#   'modularity': 0.6841710537633592,
#   'average_clustering': 0.3730781253290286,
#   'percent_cross_category_edges': 92.05298013245033},
#  {'average_degree': 12.524271844660195,
#   'average_weighted_degree': 1246.5631067961165,
#   'average_path_length': 2.2225395012373883,
#   'network_diameter': 4,
#   'graph_density': 0.12278697886921759,
#   'modularity': 0.6314062783519802,
#   'average_clustering': 0.3488994661239261,
#   'percent_cross_category_edges': 93.1782945736434},
#  {'average_degree': 12.21359223300971,
#   'average_weighted_degree': 1232.1747572815534,
#   'average_path_length': 2.2516657148296213,
#   'network_diameter': 5,
#   'graph_density': 0.11974110032362459,
#   'modularity': 0.6833567581945202,
#   'average_clustering': 0.3781398476864441,
#   'percent_cross_category_edges': 93.95866454689984},
#  {'average_degree': 12.019417475728156,
#   'average_weighted_degree': 1255.8640776699028,
#   'average_path_length': 2.2497620407386254,
#   'network_diameter': 4,
#   'graph_density': 0.11783742623262898,
#   'modularity': 0.6993739094621815,
#   'average_clustering': 0.40516413614620556,
#   'percent_cross_category_edges': 91.92245557350566},
#  {'average_degree': 12.407766990291263,
#   'average_weighted_degree': 1289.3009708737864,
#   'average_path_length': 2.2364363221016563,
#   'network_diameter': 5,
#   'graph_density': 0.12164477441462021,
#   'modularity': 0.6352720618909101,
#   'average_clustering': 0.3510591979666199,
#   'percent_cross_category_edges': 91.07981220657277},
#  {'average_degree': 13.436893203883495,
#   'average_weighted_degree': 1391.6699029126214,
#   'average_path_length': 2.14791547687036,
#   'network_diameter': 4,
#   'graph_density': 0.13173424709689702,
#   'modularity': 0.6846606456199748,
#   'average_clustering': 0.4508238803726138,
#   'percent_cross_category_edges': 92.05202312138728},
#  {'average_degree': 12.62135922330097,
#   'average_weighted_degree': 1313.3592233009708,
#   'average_path_length': 2.184656386826575,
#   'network_diameter': 5,
#   'graph_density': 0.1237388159147154,
#   'modularity': 0.7254760448436247,
#   'average_clustering': 0.42345965541772723,
#   'percent_cross_category_edges': 93.07692307692308},
#  {'average_degree': 12.757281553398059,
#   'average_weighted_degree': 1318.7572815533981,
#   'average_path_length': 2.1945554920997523,
#   'network_diameter': 5,
#   'graph_density': 0.12507138777841234,
#   'modularity': 0.6967144895786133,
#   'average_clustering': 0.41497357418206576,
#   'percent_cross_category_edges': 93.45509893455099},
#  {'average_degree': 12.640776699029127,
#   'average_weighted_degree': 1376.504854368932,
#   'average_path_length': 2.203502760327432,
#   'network_diameter': 4,
#   'graph_density': 0.12392918332381496,
#   'modularity': 0.6264190290743681,
#   'average_clustering': 0.38307966784275227,
#   'percent_cross_category_edges': 92.01228878648233},
#  {'average_degree': 12.271844660194175,
#   'average_weighted_degree': 1190.5242718446602,
#   'average_path_length': 2.2585189415572056,
#   'network_diameter': 6,
#   'graph_density': 0.12031220255092329,
#   'modularity': 0.6832239216333035,
#   'average_clustering': 0.3736768038554408,
#   'percent_cross_category_edges': 93.67088607594937},
#  {'average_degree': 12.446601941747574,
#   'average_weighted_degree': 1313.0873786407767,
#   'average_path_length': 2.197411003236246,
#   'network_diameter': 4,
#   'graph_density': 0.12202550923281934,
#   'modularity': 0.6863896824773819,
#   'average_clustering': 0.46787556858992835,
#   'percent_cross_category_edges': 91.73166926677067},
#  {'average_degree': 12.660194174757281,
#   'average_weighted_degree': 1311.611650485437,
#   'average_path_length': 2.1650485436893203,
#   'network_diameter': 4,
#   'graph_density': 0.12411955073291453,
#   'modularity': 0.6592228885229818,
#   'average_clustering': 0.40790415004645303,
#   'percent_cross_category_edges': 92.63803680981594},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1318.5436893203882,
#   'average_path_length': 2.217780316009899,
#   'network_diameter': 5,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6254360938086637,
#   'average_clustering': 0.43705873664244216,
#   'percent_cross_category_edges': 90.75500770416025},
#  {'average_degree': 12.504854368932039,
#   'average_weighted_degree': 1354.2135922330096,
#   'average_path_length': 2.206167904054826,
#   'network_diameter': 4,
#   'graph_density': 0.12259661146011802,
#   'modularity': 0.5995273528666998,
#   'average_clustering': 0.39996549700602346,
#   'percent_cross_category_edges': 93.16770186335404},
#  {'average_degree': 12.135922330097088,
#   'average_weighted_degree': 1348.116504854369,
#   'average_path_length': 2.2059775366457264,
#   'network_diameter': 4,
#   'graph_density': 0.11897963068722635,
#   'modularity': 0.7258764377507492,
#   'average_clustering': 0.3894212406159932,
#   'percent_cross_category_edges': 92.80000000000001},
#  {'average_degree': 12.330097087378642,
#   'average_weighted_degree': 1326.3106796116506,
#   'average_path_length': 2.2545212259661147,
#   'network_diameter': 4,
#   'graph_density': 0.12088330477822197,
#   'modularity': 0.6683639463557641,
#   'average_clustering': 0.4088144652557829,
#   'percent_cross_category_edges': 91.81102362204724},
#  {'average_degree': 12.25242718446602,
#   'average_weighted_degree': 1334.3495145631068,
#   'average_path_length': 2.2516657148296213,
#   'network_diameter': 4,
#   'graph_density': 0.12012183514182372,
#   'modularity': 0.7075909774908563,
#   'average_clustering': 0.38840310421083085,
#   'percent_cross_category_edges': 91.28367670364501},
#  {'average_degree': 12.679611650485437,
#   'average_weighted_degree': 1375.9029126213593,
#   'average_path_length': 2.2297734627831716,
#   'network_diameter': 5,
#   'graph_density': 0.12430991814201409,
#   'modularity': 0.7225453311239906,
#   'average_clustering': 0.35145156725911875,
#   'percent_cross_category_edges': 91.57733537519142},
#  {'average_degree': 13.572815533980583,
#   'average_weighted_degree': 1391.8058252427184,
#   'average_path_length': 2.1728536074624025,
#   'network_diameter': 4,
#   'graph_density': 0.13306681896059394,
#   'modularity': 0.6248193901833273,
#   'average_clustering': 0.42619762845503206,
#   'percent_cross_category_edges': 91.70243204577969},
#  {'average_degree': 13.009708737864077,
#   'average_weighted_degree': 1380.2330097087379,
#   'average_path_length': 2.1696173615077097,
#   'network_diameter': 4,
#   'graph_density': 0.12754616409670663,
#   'modularity': 0.6382913393718287,
#   'average_clustering': 0.4217981528898168,
#   'percent_cross_category_edges': 91.7910447761194},
#  {'average_degree': 11.941747572815533,
#   'average_weighted_degree': 1332.7766990291261,
#   'average_path_length': 2.198172472872644,
#   'network_diameter': 4,
#   'graph_density': 0.11707595659623073,
#   'modularity': 0.6890887682329979,
#   'average_clustering': 0.3650860153985278,
#   'percent_cross_category_edges': 91.869918699187},
#  {'average_degree': 12.62135922330097,
#   'average_weighted_degree': 1236.7572815533981,
#   'average_path_length': 2.1798972015990863,
#   'network_diameter': 4,
#   'graph_density': 0.1237388159147154,
#   'modularity': 0.6458729932270783,
#   'average_clustering': 0.3889012988893251,
#   'percent_cross_category_edges': 91.6923076923077},
#  {'average_degree': 11.864077669902912,
#   'average_weighted_degree': 1332.485436893204,
#   'average_path_length': 2.2562345326480107,
#   'network_diameter': 5,
#   'graph_density': 0.11631448695983247,
#   'modularity': 0.7023620469097164,
#   'average_clustering': 0.3872475170342411,
#   'percent_cross_category_edges': 90.99836333878886},
#  {'average_degree': 12.893203883495145,
#   'average_weighted_degree': 1375.514563106796,
#   'average_path_length': 2.23034456501047,
#   'network_diameter': 5,
#   'graph_density': 0.12640395964210926,
#   'modularity': 0.6692570689940202,
#   'average_clustering': 0.4010103864854431,
#   'percent_cross_category_edges': 92.7710843373494},
#  {'average_degree': 12.427184466019417,
#   'average_weighted_degree': 1366.7378640776699,
#   'average_path_length': 2.1911288787359604,
#   'network_diameter': 5,
#   'graph_density': 0.12183514182371978,
#   'modularity': 0.7255430560944559,
#   'average_clustering': 0.39424328938174646,
#   'percent_cross_category_edges': 92.1875},
#  {'average_degree': 13.436893203883495,
#   'average_weighted_degree': 1391.6699029126214,
#   'average_path_length': 2.1467732724157624,
#   'network_diameter': 4,
#   'graph_density': 0.13173424709689702,
#   'modularity': 0.6592784470970832,
#   'average_clustering': 0.45067025542319983,
#   'percent_cross_category_edges': 91.47398843930635},
#  {'average_degree': 11.611650485436893,
#   'average_weighted_degree': 1330.5631067961165,
#   'average_path_length': 2.2354844850561584,
#   'network_diameter': 4,
#   'graph_density': 0.11383971064153817,
#   'modularity': 0.6997876648900094,
#   'average_clustering': 0.3800419548701113,
#   'percent_cross_category_edges': 90.96989966555184},
#  {'average_degree': 12.83495145631068,
#   'average_weighted_degree': 1328.0970873786407,
#   'average_path_length': 2.173424709689701,
#   'network_diameter': 4,
#   'graph_density': 0.1258328574148106,
#   'modularity': 0.6377173651651806,
#   'average_clustering': 0.443172421686871,
#   'percent_cross_category_edges': 92.8895612708018},
#  {'average_degree': 12.854368932038835,
#   'average_weighted_degree': 1385.6893203883494,
#   'average_path_length': 2.220826194555492,
#   'network_diameter': 4,
#   'graph_density': 0.12602322482391015,
#   'modularity': 0.627956132619786,
#   'average_clustering': 0.38111003179143776,
#   'percent_cross_category_edges': 90.6344410876133},
#  {'average_degree': 13.553398058252426,
#   'average_weighted_degree': 1391.7864077669904,
#   'average_path_length': 2.1441081286883685,
#   'network_diameter': 4,
#   'graph_density': 0.13287645155149438,
#   'modularity': 0.6558991752768946,
#   'average_clustering': 0.4598041546857337,
#   'percent_cross_category_edges': 93.40974212034384},
#  {'average_degree': 11.883495145631068,
#   'average_weighted_degree': 1284.2135922330096,
#   'average_path_length': 2.2649914334665904,
#   'network_diameter': 5,
#   'graph_density': 0.11650485436893204,
#   'modularity': 0.7162827361315708,
#   'average_clustering': 0.35569250967531674,
#   'percent_cross_category_edges': 91.83006535947712},
#  {'average_degree': 12.990291262135923,
#   'average_weighted_degree': 1385.126213592233,
#   'average_path_length': 2.156101275461641,
#   'network_diameter': 4,
#   'graph_density': 0.12735579668760708,
#   'modularity': 0.6507142091674839,
#   'average_clustering': 0.45756985406797523,
#   'percent_cross_category_edges': 92.82511210762333},
#  {'average_degree': 12.640776699029127,
#   'average_weighted_degree': 1338.1941747572816,
#   'average_path_length': 2.205596801827527,
#   'network_diameter': 5,
#   'graph_density': 0.12392918332381496,
#   'modularity': 0.731751108414702,
#   'average_clustering': 0.4022499679808328,
#   'percent_cross_category_edges': 92.78033794162826},
#  {'average_degree': 12.62135922330097,
#   'average_weighted_degree': 1315.883495145631,
#   'average_path_length': 2.1966495335998477,
#   'network_diameter': 4,
#   'graph_density': 0.1237388159147154,
#   'modularity': 0.7112547893677221,
#   'average_clustering': 0.4256340609499673,
#   'percent_cross_category_edges': 92.3076923076923},
#  {'average_degree': 11.922330097087379,
#   'average_weighted_degree': 1235.009708737864,
#   'average_path_length': 2.2598515134209025,
#   'network_diameter': 4,
#   'graph_density': 0.11688558918713117,
#   'modularity': 0.6965747433370836,
#   'average_clustering': 0.3677270559463176,
#   'percent_cross_category_edges': 90.87947882736157},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1376.6601941747572,
#   'average_path_length': 2.207500475918523,
#   'network_diameter': 4,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6377318895508183,
#   'average_clustering': 0.36374351422330553,
#   'percent_cross_category_edges': 91.83359013867488},
#  {'average_degree': 12.174757281553399,
#   'average_weighted_degree': 1252.1359223300972,
#   'average_path_length': 2.286502950694841,
#   'network_diameter': 5,
#   'graph_density': 0.11936036550542548,
#   'modularity': 0.6206227945357365,
#   'average_clustering': 0.36457498146205713,
#   'percent_cross_category_edges': 92.50398724082935},
#  {'average_degree': 12.815533980582524,
#   'average_weighted_degree': 1386.6601941747572,
#   'average_path_length': 2.2090234151913193,
#   'network_diameter': 5,
#   'graph_density': 0.125642490005711,
#   'modularity': 0.6926141989049254,
#   'average_clustering': 0.4106967588008141,
#   'percent_cross_category_edges': 92.72727272727272},
#  {'average_degree': 12.058252427184467,
#   'average_weighted_degree': 1271.3980582524273,
#   'average_path_length': 2.2821245002855512,
#   'network_diameter': 5,
#   'graph_density': 0.1182181610508281,
#   'modularity': 0.7037899084410632,
#   'average_clustering': 0.3691207617914261,
#   'percent_cross_category_edges': 92.7536231884058},
#  {'average_degree': 12.271844660194175,
#   'average_weighted_degree': 1306.2330097087379,
#   'average_path_length': 2.262707024557396,
#   'network_diameter': 5,
#   'graph_density': 0.12031220255092329,
#   'modularity': 0.6795404066707843,
#   'average_clustering': 0.4365818850624925,
#   'percent_cross_category_edges': 91.77215189873418},
#  {'average_degree': 12.097087378640778,
#   'average_weighted_degree': 1303.7475728155339,
#   'average_path_length': 2.237388159147154,
#   'network_diameter': 5,
#   'graph_density': 0.11859889586902722,
#   'modularity': 0.6751455786078813,
#   'average_clustering': 0.4472204823881095,
#   'percent_cross_category_edges': 92.776886035313},
#  {'average_degree': 12.79611650485437,
#   'average_weighted_degree': 1380.485436893204,
#   'average_path_length': 2.231677136874167,
#   'network_diameter': 5,
#   'graph_density': 0.12545212259661145,
#   'modularity': 0.6853809899587427,
#   'average_clustering': 0.38084507389903416,
#   'percent_cross_category_edges': 91.95751138088012},
#  {'average_degree': 12.912621359223301,
#   'average_weighted_degree': 1387.8252427184466,
#   'average_path_length': 2.174376546735199,
#   'network_diameter': 4,
#   'graph_density': 0.12659432705120882,
#   'modularity': 0.6460148090827077,
#   'average_clustering': 0.4209664382615769,
#   'percent_cross_category_edges': 91.57894736842105},
#  {'average_degree': 12.54368932038835,
#   'average_weighted_degree': 1378.4271844660195,
#   'average_path_length': 2.2244431753283838,
#   'network_diameter': 4,
#   'graph_density': 0.12297734627831715,
#   'modularity': 0.6589905153634488,
#   'average_clustering': 0.38260234600887183,
#   'percent_cross_category_edges': 92.26006191950464},
#  {'average_degree': 12.0,
#   'average_weighted_degree': 1272.4077669902913,
#   'average_path_length': 2.25223681705692,
#   'network_diameter': 4,
#   'graph_density': 0.11764705882352941,
#   'modularity': 0.688773499380535,
#   'average_clustering': 0.3938032533074417,
#   'percent_cross_category_edges': 93.36569579288026},
#  {'average_degree': 13.009708737864077,
#   'average_weighted_degree': 1390.0776699029127,
#   'average_path_length': 2.1661907481439178,
#   'network_diameter': 4,
#   'graph_density': 0.12754616409670663,
#   'modularity': 0.6084660535726091,
#   'average_clustering': 0.4179770511480405,
#   'percent_cross_category_edges': 91.49253731343283},
#  {'average_degree': 12.388349514563107,
#   'average_weighted_degree': 1334.4466019417475,
#   'average_path_length': 2.192271083190558,
#   'network_diameter': 4,
#   'graph_density': 0.12145440700552065,
#   'modularity': 0.666241296027331,
#   'average_clustering': 0.3890096240211775,
#   'percent_cross_category_edges': 92.31974921630093},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1369.106796116505,
#   'average_path_length': 2.2046449647820294,
#   'network_diameter': 5,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.661624731778838,
#   'average_clustering': 0.39078843538383357,
#   'percent_cross_category_edges': 91.83359013867488},
#  {'average_degree': 12.679611650485437,
#   'average_weighted_degree': 1374.8155339805826,
#   'average_path_length': 2.2063582714639254,
#   'network_diameter': 4,
#   'graph_density': 0.12430991814201409,
#   'modularity': 0.6712241362726815,
#   'average_clustering': 0.43712749597458583,
#   'percent_cross_category_edges': 91.88361408882083},
#  {'average_degree': 13.300970873786408,
#   'average_weighted_degree': 1391.5339805825242,
#   'average_path_length': 2.1979821054635447,
#   'network_diameter': 5,
#   'graph_density': 0.13040167523320007,
#   'modularity': 0.6337212534787194,
#   'average_clustering': 0.40112758331766607,
#   'percent_cross_category_edges': 93.43065693430657},
#  {'average_degree': 12.854368932038835,
#   'average_weighted_degree': 1376.9126213592233,
#   'average_path_length': 2.2181610508280984,
#   'network_diameter': 5,
#   'graph_density': 0.12602322482391015,
#   'modularity': 0.6580082638076857,
#   'average_clustering': 0.3683247269893993,
#   'percent_cross_category_edges': 90.6344410876133},
#  {'average_degree': 12.388349514563107,
#   'average_weighted_degree': 1367.3203883495146,
#   'average_path_length': 2.2333904435560634,
#   'network_diameter': 4,
#   'graph_density': 0.12145440700552065,
#   'modularity': 0.7194806595556594,
#   'average_clustering': 0.4025724611226741,
#   'percent_cross_category_edges': 91.84952978056427},
#  {'average_degree': 12.699029126213592,
#   'average_weighted_degree': 1385.0485436893205,
#   'average_path_length': 2.197220635827146,
#   'network_diameter': 5,
#   'graph_density': 0.12450028555111364,
#   'modularity': 0.6407742219100435,
#   'average_clustering': 0.39369143557543657,
#   'percent_cross_category_edges': 91.89602446483181},
#  {'average_degree': 12.893203883495145,
#   'average_weighted_degree': 1388.9126213592233,
#   'average_path_length': 2.191890348372359,
#   'network_diameter': 4,
#   'graph_density': 0.12640395964210926,
#   'modularity': 0.67346339653027,
#   'average_clustering': 0.4126072925146573,
#   'percent_cross_category_edges': 91.56626506024097},
#  {'average_degree': 12.699029126213592,
#   'average_weighted_degree': 1355.3009708737864,
#   'average_path_length': 2.1966495335998477,
#   'network_diameter': 4,
#   'graph_density': 0.12450028555111364,
#   'modularity': 0.6946479084567141,
#   'average_clustering': 0.43080320168931613,
#   'percent_cross_category_edges': 91.13149847094802},
#  {'average_degree': 12.504854368932039,
#   'average_weighted_degree': 1269.7087378640776,
#   'average_path_length': 2.1989339425090426,
#   'network_diameter': 5,
#   'graph_density': 0.12259661146011802,
#   'modularity': 0.6829294373862932,
#   'average_clustering': 0.4076589687615053,
#   'percent_cross_category_edges': 91.61490683229813},
#  {'average_degree': 12.54368932038835,
#   'average_weighted_degree': 1363.126213592233,
#   'average_path_length': 2.2377688939653533,
#   'network_diameter': 5,
#   'graph_density': 0.12297734627831715,
#   'modularity': 0.6861657028248873,
#   'average_clustering': 0.37684810791370743,
#   'percent_cross_category_edges': 92.10526315789474},
#  {'average_degree': 12.990291262135923,
#   'average_weighted_degree': 1390.5436893203882,
#   'average_path_length': 2.183323814962878,
#   'network_diameter': 4,
#   'graph_density': 0.12735579668760708,
#   'modularity': 0.654524584890865,
#   'average_clustering': 0.44226269581504457,
#   'percent_cross_category_edges': 90.5829596412556},
#  {'average_degree': 12.407766990291263,
#   'average_weighted_degree': 1284.0388349514562,
#   'average_path_length': 2.174376546735199,
#   'network_diameter': 4,
#   'graph_density': 0.12164477441462021,
#   'modularity': 0.7007616652033063,
#   'average_clustering': 0.45982180375289033,
#   'percent_cross_category_edges': 91.70579029733959},
#  {'average_degree': 12.854368932038835,
#   'average_weighted_degree': 1380.1359223300972,
#   'average_path_length': 2.251475347420522,
#   'network_diameter': 5,
#   'graph_density': 0.12602322482391015,
#   'modularity': 0.6541071668391962,
#   'average_clustering': 0.3756583445776369,
#   'percent_cross_category_edges': 92.29607250755288},
#  {'average_degree': 12.932038834951456,
#   'average_weighted_degree': 1388.368932038835,
#   'average_path_length': 2.2046449647820294,
#   'network_diameter': 5,
#   'graph_density': 0.1267846944603084,
#   'modularity': 0.6382565086177341,
#   'average_clustering': 0.37031782815017217,
#   'percent_cross_category_edges': 91.14114114114115},
#  {'average_degree': 12.563106796116505,
#   'average_weighted_degree': 1316.2330097087379,
#   'average_path_length': 2.2029316581001335,
#   'network_diameter': 4,
#   'graph_density': 0.12316771368741672,
#   'modularity': 0.6573272260226035,
#   'average_clustering': 0.390524855289645,
#   'percent_cross_category_edges': 92.73570324574962},
#  {'average_degree': 12.54368932038835,
#   'average_weighted_degree': 1372.0582524271845,
#   'average_path_length': 2.1498191509613553,
#   'network_diameter': 4,
#   'graph_density': 0.12297734627831715,
#   'modularity': 0.7236511683647736,
#   'average_clustering': 0.4179412643787669,
#   'percent_cross_category_edges': 93.03405572755418},
#  {'average_degree': 12.79611650485437,
#   'average_weighted_degree': 1380.0388349514562,
#   'average_path_length': 2.208261945554921,
#   'network_diameter': 6,
#   'graph_density': 0.12545212259661145,
#   'modularity': 0.6378421315163196,
#   'average_clustering': 0.42795063699764807,
#   'percent_cross_category_edges': 91.95751138088012},
#  {'average_degree': 13.281553398058252,
#   'average_weighted_degree': 1391.514563106796,
#   'average_path_length': 2.1225966114601182,
#   'network_diameter': 4,
#   'graph_density': 0.1302113078241005,
#   'modularity': 0.6500003321237622,
#   'average_clustering': 0.4343983277191763,
#   'percent_cross_category_edges': 92.2514619883041},
#  {'average_degree': 12.54368932038835,
#   'average_weighted_degree': 1368.1553398058252,
#   'average_path_length': 2.186560060917571,
#   'network_diameter': 4,
#   'graph_density': 0.12297734627831715,
#   'modularity': 0.6631743791397499,
#   'average_clustering': 0.44127428064906377,
#   'percent_cross_category_edges': 90.40247678018576},
#  {'average_degree': 12.83495145631068,
#   'average_weighted_degree': 1384.1941747572816,
#   'average_path_length': 2.2202550923281934,
#   'network_diameter': 5,
#   'graph_density': 0.1258328574148106,
#   'modularity': 0.7140070677528875,
#   'average_clustering': 0.3771110504248451,
#   'percent_cross_category_edges': 92.28441754916793},
#  {'average_degree': 12.932038834951456,
#   'average_weighted_degree': 1361.0485436893205,
#   'average_path_length': 2.1848467542356746,
#   'network_diameter': 4,
#   'graph_density': 0.1267846944603084,
#   'modularity': 0.689134442865297,
#   'average_clustering': 0.41745459618436653,
#   'percent_cross_category_edges': 92.34234234234235},
#  {'average_degree': 12.446601941747574,
#   'average_weighted_degree': 1341.126213592233,
#   'average_path_length': 2.2510946126023224,
#   'network_diameter': 5,
#   'graph_density': 0.12202550923281934,
#   'modularity': 0.6261036514873258,
#   'average_clustering': 0.4072688818224972,
#   'percent_cross_category_edges': 92.97971918876755},
#  {'average_degree': 13.300970873786408,
#   'average_weighted_degree': 1391.5339805825242,
#   'average_path_length': 2.1629545021892254,
#   'network_diameter': 5,
#   'graph_density': 0.13040167523320007,
#   'modularity': 0.6704053057943968,
#   'average_clustering': 0.41166881126060484,
#   'percent_cross_category_edges': 92.7007299270073},
#  {'average_degree': 12.21359223300971,
#   'average_weighted_degree': 1293.4757281553398,
#   'average_path_length': 2.261374452693699,
#   'network_diameter': 5,
#   'graph_density': 0.11974110032362459,
#   'modularity': 0.6987833836729935,
#   'average_clustering': 0.3869031564926579,
#   'percent_cross_category_edges': 92.68680445151033},
#  {'average_degree': 13.067961165048544,
#   'average_weighted_degree': 1389.2621359223301,
#   'average_path_length': 2.1758994860079954,
#   'network_diameter': 4,
#   'graph_density': 0.12811726632400533,
#   'modularity': 0.7020427284482785,
#   'average_clustering': 0.4171194303352962,
#   'percent_cross_category_edges': 91.53046062407132},
#  {'average_degree': 11.941747572815533,
#   'average_weighted_degree': 1278.5242718446602,
#   'average_path_length': 2.212450028555111,
#   'network_diameter': 4,
#   'graph_density': 0.11707595659623073,
#   'modularity': 0.6647787926634129,
#   'average_clustering': 0.40109454123585625,
#   'percent_cross_category_edges': 91.21951219512195},
#  {'average_degree': 12.718446601941748,
#   'average_weighted_degree': 1380.621359223301,
#   'average_path_length': 2.188654102417666,
#   'network_diameter': 4,
#   'graph_density': 0.12469065296021321,
#   'modularity': 0.702386375937921,
#   'average_clustering': 0.4091658057149061,
#   'percent_cross_category_edges': 91.45038167938931},
#  {'average_degree': 12.466019417475728,
#   'average_weighted_degree': 1300.621359223301,
#   'average_path_length': 2.2476679992385304,
#   'network_diameter': 5,
#   'graph_density': 0.12221587664191891,
#   'modularity': 0.6923180616738037,
#   'average_clustering': 0.3745490755856283,
#   'percent_cross_category_edges': 91.90031152647975},
#  {'average_degree': 11.78640776699029,
#   'average_weighted_degree': 1249.7475728155339,
#   'average_path_length': 2.2608033504664,
#   'network_diameter': 5,
#   'graph_density': 0.11555301732343423,
#   'modularity': 0.6473669433011426,
#   'average_clustering': 0.4166976053497762,
#   'percent_cross_category_edges': 91.92751235584844},
#  {'average_degree': 13.16504854368932,
#   'average_weighted_degree': 1391.3980582524273,
#   'average_path_length': 2.2097848848277173,
#   'network_diameter': 5,
#   'graph_density': 0.12906910336950314,
#   'modularity': 0.6663357268496586,
#   'average_clustering': 0.3883841592004646,
#   'percent_cross_category_edges': 92.77286135693215},
#  {'average_degree': 12.990291262135923,
#   'average_weighted_degree': 1386.5631067961165,
#   'average_path_length': 2.1732343422806015,
#   'network_diameter': 4,
#   'graph_density': 0.12735579668760708,
#   'modularity': 0.6498927618921446,
#   'average_clustering': 0.4414865824457231,
#   'percent_cross_category_edges': 92.82511210762333},
#  {'average_degree': 12.679611650485437,
#   'average_weighted_degree': 1319.8640776699028,
#   'average_path_length': 2.2153055396916046,
#   'network_diameter': 5,
#   'graph_density': 0.12430991814201409,
#   'modularity': 0.6428700990162814,
#   'average_clustering': 0.4115780858359306,
#   'percent_cross_category_edges': 92.03675344563553},
#  {'average_degree': 11.902912621359222,
#   'average_weighted_degree': 1267.1844660194174,
#   'average_path_length': 2.2484294688749284,
#   'network_diameter': 4,
#   'graph_density': 0.1166952217780316,
#   'modularity': 0.6863475255722906,
#   'average_clustering': 0.38120425212806064,
#   'percent_cross_category_edges': 93.6378466557912},
#  {'average_degree': 12.155339805825243,
#   'average_weighted_degree': 1361.0873786407767,
#   'average_path_length': 2.2410051399200457,
#   'network_diameter': 5,
#   'graph_density': 0.1191699980963259,
#   'modularity': 0.6947872381347515,
#   'average_clustering': 0.38548696002447463,
#   'percent_cross_category_edges': 93.76996805111821},
#  {'average_degree': 12.25242718446602,
#   'average_weighted_degree': 1337.9029126213593,
#   'average_path_length': 2.236245954692557,
#   'network_diameter': 4,
#   'graph_density': 0.12012183514182372,
#   'modularity': 0.7055916264764729,
#   'average_clustering': 0.3850597979861234,
#   'percent_cross_category_edges': 90.01584786053883},
#  {'average_degree': 12.660194174757281,
#   'average_weighted_degree': 1373.3009708737864,
#   'average_path_length': 2.2185417856462974,
#   'network_diameter': 5,
#   'graph_density': 0.12411955073291453,
#   'modularity': 0.7015704693635991,
#   'average_clustering': 0.43675375276621786,
#   'percent_cross_category_edges': 92.48466257668711},
#  {'average_degree': 13.145631067961165,
#   'average_weighted_degree': 1391.378640776699,
#   'average_path_length': 2.163525604416524,
#   'network_diameter': 4,
#   'graph_density': 0.12887873596040358,
#   'modularity': 0.618401277108277,
#   'average_clustering': 0.4082260572891931,
#   'percent_cross_category_edges': 92.31905465288035},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1335.611650485437,
#   'average_path_length': 2.1749476489624975,
#   'network_diameter': 4,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6905273249864147,
#   'average_clustering': 0.4430972984790675,
#   'percent_cross_category_edges': 92.44992295839754},
#  {'average_degree': 12.330097087378642,
#   'average_weighted_degree': 1288.368932038835,
#   'average_path_length': 2.2598515134209025,
#   'network_diameter': 6,
#   'graph_density': 0.12088330477822197,
#   'modularity': 0.676065376389051,
#   'average_clustering': 0.39134904314167557,
#   'percent_cross_category_edges': 90.86614173228347},
#  {'average_degree': 12.660194174757281,
#   'average_weighted_degree': 1197.2233009708739,
#   'average_path_length': 2.2139729678279076,
#   'network_diameter': 5,
#   'graph_density': 0.12411955073291453,
#   'modularity': 0.6381438386474717,
#   'average_clustering': 0.40143273385484357,
#   'percent_cross_category_edges': 92.33128834355828},
#  {'average_degree': 12.970873786407767,
#   'average_weighted_degree': 1385.9223300970873,
#   'average_path_length': 2.2111174566914142,
#   'network_diameter': 5,
#   'graph_density': 0.12716542927850752,
#   'modularity': 0.684908612499655,
#   'average_clustering': 0.44033864034486614,
#   'percent_cross_category_edges': 92.36526946107784},
#  {'average_degree': 12.699029126213592,
#   'average_weighted_degree': 1385.009708737864,
#   'average_path_length': 2.188654102417666,
#   'network_diameter': 5,
#   'graph_density': 0.12450028555111364,
#   'modularity': 0.6041164419434147,
#   'average_clustering': 0.4004478732591821,
#   'percent_cross_category_edges': 92.20183486238533},
#  {'average_degree': 12.349514563106796,
#   'average_weighted_degree': 1268.8349514563106,
#   'average_path_length': 2.2345326480106604,
#   'network_diameter': 5,
#   'graph_density': 0.12107367218732153,
#   'modularity': 0.6856756404690781,
#   'average_clustering': 0.3664013127485964,
#   'percent_cross_category_edges': 91.98113207547169},
#  {'average_degree': 13.048543689320388,
#   'average_weighted_degree': 1389.0291262135922,
#   'average_path_length': 2.150580620597754,
#   'network_diameter': 4,
#   'graph_density': 0.12792689891490577,
#   'modularity': 0.6153695123014873,
#   'average_clustering': 0.4209984113014327,
#   'percent_cross_category_edges': 91.51785714285714},
#  {'average_degree': 12.233009708737864,
#   'average_weighted_degree': 1301.5728155339805,
#   'average_path_length': 2.212450028555111,
#   'network_diameter': 5,
#   'graph_density': 0.11993146773272416,
#   'modularity': 0.6760352247730991,
#   'average_clustering': 0.4386584756419689,
#   'percent_cross_category_edges': 91.9047619047619},
#  {'average_degree': 12.893203883495145,
#   'average_weighted_degree': 1353.7864077669904,
#   'average_path_length': 2.205216067009328,
#   'network_diameter': 4,
#   'graph_density': 0.12640395964210926,
#   'modularity': 0.6877172008664113,
#   'average_clustering': 0.40361604860867145,
#   'percent_cross_category_edges': 91.41566265060241},
#  {'average_degree': 12.854368932038835,
#   'average_weighted_degree': 1382.5631067961165,
#   'average_path_length': 2.160098991052732,
#   'network_diameter': 4,
#   'graph_density': 0.12602322482391015,
#   'modularity': 0.6957911519609181,
#   'average_clustering': 0.4327860683500464,
#   'percent_cross_category_edges': 93.65558912386706},
#  {'average_degree': 12.485436893203884,
#   'average_weighted_degree': 1368.3495145631068,
#   'average_path_length': 2.2318675042832665,
#   'network_diameter': 4,
#   'graph_density': 0.12240624405101846,
#   'modularity': 0.701882885954024,
#   'average_clustering': 0.38706393404770895,
#   'percent_cross_category_edges': 92.2239502332815},
#  {'average_degree': 12.504854368932039,
#   'average_weighted_degree': 1352.8349514563106,
#   'average_path_length': 2.1871311631448696,
#   'network_diameter': 5,
#   'graph_density': 0.12259661146011802,
#   'modularity': 0.7153700722769558,
#   'average_clustering': 0.3898558869987074,
#   'percent_cross_category_edges': 91.92546583850931},
#  {'average_degree': 12.155339805825243,
#   'average_weighted_degree': 1349.6504854368932,
#   'average_path_length': 2.225204644964782,
#   'network_diameter': 4,
#   'graph_density': 0.1191699980963259,
#   'modularity': 0.6909271121710945,
#   'average_clustering': 0.42399108570776584,
#   'percent_cross_category_edges': 91.85303514376997},
#  {'average_degree': 12.54368932038835,
#   'average_weighted_degree': 1323.3980582524273,
#   'average_path_length': 2.179706834189987,
#   'network_diameter': 4,
#   'graph_density': 0.12297734627831715,
#   'modularity': 0.7199938498686259,
#   'average_clustering': 0.4206527533449696,
#   'percent_cross_category_edges': 93.03405572755418},
#  {'average_degree': 12.815533980582524,
#   'average_weighted_degree': 1320.485436893204,
#   'average_path_length': 2.1572434799162385,
#   'network_diameter': 4,
#   'graph_density': 0.125642490005711,
#   'modularity': 0.6714500209125279,
#   'average_clustering': 0.4129140342733427,
#   'percent_cross_category_edges': 91.06060606060606},
#  {'average_degree': 12.737864077669903,
#   'average_weighted_degree': 1384.4271844660195,
#   'average_path_length': 2.205216067009328,
#   'network_diameter': 4,
#   'graph_density': 0.12488102036931277,
#   'modularity': 0.649830487117744,
#   'average_clustering': 0.41265777755756755,
#   'percent_cross_category_edges': 91.15853658536585},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1347.5533980582525,
#   'average_path_length': 2.223491338282886,
#   'network_diameter': 5,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6962073108900797,
#   'average_clustering': 0.4042312090847917,
#   'percent_cross_category_edges': 92.14175654853621},
#  {'average_degree': 12.951456310679612,
#   'average_weighted_degree': 1382.2135922330096,
#   'average_path_length': 2.173424709689701,
#   'network_diameter': 5,
#   'graph_density': 0.12697506186940796,
#   'modularity': 0.6982079763863773,
#   'average_clustering': 0.46386965421952653,
#   'percent_cross_category_edges': 91.45427286356822},
#  {'average_degree': 12.29126213592233,
#   'average_weighted_degree': 1325.9805825242718,
#   'average_path_length': 2.218732153055397,
#   'network_diameter': 4,
#   'graph_density': 0.12050256996002284,
#   'modularity': 0.682156763961618,
#   'average_clustering': 0.395103080808351,
#   'percent_cross_category_edges': 93.04897314375987},
#  {'average_degree': 12.407766990291263,
#   'average_weighted_degree': 1291.9611650485438,
#   'average_path_length': 2.206167904054826,
#   'network_diameter': 4,
#   'graph_density': 0.12164477441462021,
#   'modularity': 0.6717436721618836,
#   'average_clustering': 0.3936450910803286,
#   'percent_cross_category_edges': 91.70579029733959},
#  {'average_degree': 12.776699029126213,
#   'average_weighted_degree': 1326.5242718446602,
#   'average_path_length': 2.1789453645535883,
#   'network_diameter': 4,
#   'graph_density': 0.1252617551875119,
#   'modularity': 0.6991201407847869,
#   'average_clustering': 0.4196155935241234,
#   'percent_cross_category_edges': 93.00911854103343},
#  {'average_degree': 12.58252427184466,
#   'average_weighted_degree': 1186.7766990291261,
#   'average_path_length': 2.2193032552826955,
#   'network_diameter': 5,
#   'graph_density': 0.12335808109651628,
#   'modularity': 0.6354329031836168,
#   'average_clustering': 0.35407713923639744,
#   'percent_cross_category_edges': 92.90123456790124},
#  {'average_degree': 12.135922330097088,
#   'average_weighted_degree': 1289.6699029126214,
#   'average_path_length': 2.202550923281934,
#   'network_diameter': 4,
#   'graph_density': 0.11897963068722635,
#   'modularity': 0.666287900327011,
#   'average_clustering': 0.43435221494535947,
#   'percent_cross_category_edges': 92.32000000000001},
#  {'average_degree': 12.310679611650485,
#   'average_weighted_degree': 1295.2038834951456,
#   'average_path_length': 2.229011993146773,
#   'network_diameter': 5,
#   'graph_density': 0.1206929373691224,
#   'modularity': 0.665942355593375,
#   'average_clustering': 0.37776746610512196,
#   'percent_cross_category_edges': 93.05993690851734},
#  {'average_degree': 12.718446601941748,
#   'average_weighted_degree': 1369.6699029126214,
#   'average_path_length': 2.206548638873025,
#   'network_diameter': 5,
#   'graph_density': 0.12469065296021321,
#   'modularity': 0.5983087285096005,
#   'average_clustering': 0.34566315134816045,
#   'percent_cross_category_edges': 92.06106870229007},
#  {'average_degree': 12.116504854368932,
#   'average_weighted_degree': 1306.990291262136,
#   'average_path_length': 2.2246335427374833,
#   'network_diameter': 4,
#   'graph_density': 0.11878926327812679,
#   'modularity': 0.6747094444420288,
#   'average_clustering': 0.36841772849291965,
#   'percent_cross_category_edges': 91.18589743589743},
#  {'average_degree': 12.679611650485437,
#   'average_weighted_degree': 1342.6601941747572,
#   'average_path_length': 2.189034837235865,
#   'network_diameter': 4,
#   'graph_density': 0.12430991814201409,
#   'modularity': 0.6612274709221705,
#   'average_clustering': 0.4400186633238181,
#   'percent_cross_category_edges': 91.57733537519142},
#  {'average_degree': 12.388349514563107,
#   'average_weighted_degree': 1166.990291262136,
#   'average_path_length': 2.208261945554921,
#   'network_diameter': 5,
#   'graph_density': 0.12145440700552065,
#   'modularity': 0.6428153716351838,
#   'average_clustering': 0.42206867331307985,
#   'percent_cross_category_edges': 94.04388714733543},
#  {'average_degree': 12.563106796116505,
#   'average_weighted_degree': 1374.2135922330096,
#   'average_path_length': 2.2073101085094233,
#   'network_diameter': 4,
#   'graph_density': 0.12316771368741672,
#   'modularity': 0.6637234486957382,
#   'average_clustering': 0.43106694016942615,
#   'percent_cross_category_edges': 92.11746522411129},
#  {'average_degree': 12.504854368932039,
#   'average_weighted_degree': 1378.9514563106795,
#   'average_path_length': 2.223491338282886,
#   'network_diameter': 4,
#   'graph_density': 0.12259661146011802,
#   'modularity': 0.6787591087170528,
#   'average_clustering': 0.37983555262760527,
#   'percent_cross_category_edges': 92.3913043478261},
#  {'average_degree': 12.718446601941748,
#   'average_weighted_degree': 1381.2038834951456,
#   'average_path_length': 2.2162573767371025,
#   'network_diameter': 5,
#   'graph_density': 0.12469065296021321,
#   'modularity': 0.6636869625060804,
#   'average_clustering': 0.4226091089665495,
#   'percent_cross_category_edges': 92.06106870229007},
#  {'average_degree': 12.233009708737864,
#   'average_weighted_degree': 1236.5436893203882,
#   'average_path_length': 2.236055587283457,
#   'network_diameter': 5,
#   'graph_density': 0.11993146773272416,
#   'modularity': 0.6910545519487329,
#   'average_clustering': 0.39541405589854667,
#   'percent_cross_category_edges': 91.74603174603175},
#  {'average_degree': 12.135922330097088,
#   'average_weighted_degree': 1312.3106796116506,
#   'average_path_length': 2.2507138777841234,
#   'network_diameter': 5,
#   'graph_density': 0.11897963068722635,
#   'modularity': 0.6991499121633552,
#   'average_clustering': 0.423724017413561,
#   'percent_cross_category_edges': 93.76},
#  {'average_degree': 12.310679611650485,
#   'average_weighted_degree': 1353.4757281553398,
#   'average_path_length': 2.2358652198743574,
#   'network_diameter': 4,
#   'graph_density': 0.1206929373691224,
#   'modularity': 0.6537015944603133,
#   'average_clustering': 0.3922768155032117,
#   'percent_cross_category_edges': 92.11356466876973},
#  {'average_degree': 12.912621359223301,
#   'average_weighted_degree': 1385.2233009708739,
#   'average_path_length': 2.189034837235865,
#   'network_diameter': 4,
#   'graph_density': 0.12659432705120882,
#   'modularity': 0.6703988135314762,
#   'average_clustering': 0.4199793098148968,
#   'percent_cross_category_edges': 91.72932330827066},
#  {'average_degree': 12.466019417475728,
#   'average_weighted_degree': 1285.3009708737864,
#   'average_path_length': 2.1962687987816487,
#   'network_diameter': 4,
#   'graph_density': 0.12221587664191891,
#   'modularity': 0.7054849670271989,
#   'average_clustering': 0.4090164135138346,
#   'percent_cross_category_edges': 91.43302180685359},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1350.0970873786407,
#   'average_path_length': 2.2139729678279076,
#   'network_diameter': 4,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6812485273055146,
#   'average_clustering': 0.36800377166905834,
#   'percent_cross_category_edges': 91.06317411402158},
#  {'average_degree': 13.048543689320388,
#   'average_weighted_degree': 1387.3203883495146,
#   'average_path_length': 2.1941747572815533,
#   'network_diameter': 4,
#   'graph_density': 0.12792689891490577,
#   'modularity': 0.6581858595110087,
#   'average_clustering': 0.42518120745452614,
#   'percent_cross_category_edges': 91.96428571428571},
#  {'average_degree': 12.951456310679612,
#   'average_weighted_degree': 1382.116504854369,
#   'average_path_length': 2.1880830001903675,
#   'network_diameter': 4,
#   'graph_density': 0.12697506186940796,
#   'modularity': 0.7045550676732707,
#   'average_clustering': 0.38088065647108804,
#   'percent_cross_category_edges': 92.50374812593704},
#  {'average_degree': 12.757281553398059,
#   'average_weighted_degree': 1360.990291262136,
#   'average_path_length': 2.2073101085094233,
#   'network_diameter': 5,
#   'graph_density': 0.12507138777841234,
#   'modularity': 0.6703269871847928,
#   'average_clustering': 0.4282841381493236,
#   'percent_cross_category_edges': 90.71537290715372},
#  {'average_degree': 12.097087378640778,
#   'average_weighted_degree': 1306.7184466019417,
#   'average_path_length': 2.2225395012373883,
#   'network_diameter': 4,
#   'graph_density': 0.11859889586902722,
#   'modularity': 0.6633394837523365,
#   'average_clustering': 0.40978055202805785,
#   'percent_cross_category_edges': 91.49277688603532},
#  {'average_degree': 13.087378640776699,
#   'average_weighted_degree': 1391.0485436893205,
#   'average_path_length': 2.202170188463735,
#   'network_diameter': 5,
#   'graph_density': 0.1283076337331049,
#   'modularity': 0.6913885149729346,
#   'average_clustering': 0.43448392717478745,
#   'percent_cross_category_edges': 92.87833827893175},
#  {'average_degree': 12.427184466019417,
#   'average_weighted_degree': 1190.0582524271845,
#   'average_path_length': 2.225585379782981,
#   'network_diameter': 4,
#   'graph_density': 0.12183514182371978,
#   'modularity': 0.6529543732847964,
#   'average_clustering': 0.41674741289720235,
#   'percent_cross_category_edges': 92.96875},
#  {'average_degree': 12.737864077669903,
#   'average_weighted_degree': 1375.7281553398059,
#   'average_path_length': 2.2693698838758802,
#   'network_diameter': 5,
#   'graph_density': 0.12488102036931277,
#   'modularity': 0.6322052375405214,
#   'average_clustering': 0.3883720315890935,
#   'percent_cross_category_edges': 91.61585365853658},
#  {'average_degree': 12.097087378640778,
#   'average_weighted_degree': 1310.2135922330096,
#   'average_path_length': 2.2844089091947457,
#   'network_diameter': 5,
#   'graph_density': 0.11859889586902722,
#   'modularity': 0.6134240537946863,
#   'average_clustering': 0.4400401635001128,
#   'percent_cross_category_edges': 92.29534510433388},
#  {'average_degree': 13.009708737864077,
#   'average_weighted_degree': 1363.7087378640776,
#   'average_path_length': 2.182943080144679,
#   'network_diameter': 4,
#   'graph_density': 0.12754616409670663,
#   'modularity': 0.6848110473523119,
#   'average_clustering': 0.4541671401992882,
#   'percent_cross_category_edges': 92.6865671641791},
#  {'average_degree': 12.466019417475728,
#   'average_weighted_degree': 1240.0776699029127,
#   'average_path_length': 2.2000761469636396,
#   'network_diameter': 4,
#   'graph_density': 0.12221587664191891,
#   'modularity': 0.7011798365655949,
#   'average_clustering': 0.465950939917854,
#   'percent_cross_category_edges': 92.6791277258567},
#  {'average_degree': 12.466019417475728,
#   'average_weighted_degree': 1349.3203883495146,
#   'average_path_length': 2.2193032552826955,
#   'network_diameter': 4,
#   'graph_density': 0.12221587664191891,
#   'modularity': 0.6492087362398427,
#   'average_clustering': 0.37495615910487395,
#   'percent_cross_category_edges': 92.05607476635514},
#  {'average_degree': 12.349514563106796,
#   'average_weighted_degree': 1274.8349514563106,
#   'average_path_length': 2.2284408909194746,
#   'network_diameter': 4,
#   'graph_density': 0.12107367218732153,
#   'modularity': 0.6417771581433561,
#   'average_clustering': 0.3468863083152008,
#   'percent_cross_category_edges': 91.98113207547169},
#  {'average_degree': 12.524271844660195,
#   'average_weighted_degree': 1331.009708737864,
#   'average_path_length': 2.2179706834189985,
#   'network_diameter': 4,
#   'graph_density': 0.12278697886921759,
#   'modularity': 0.6721303549275226,
#   'average_clustering': 0.4089218296043447,
#   'percent_cross_category_edges': 91.93798449612403},
#  {'average_degree': 12.699029126213592,
#   'average_weighted_degree': 1213.883495145631,
#   'average_path_length': 2.1768513230534934,
#   'network_diameter': 4,
#   'graph_density': 0.12450028555111364,
#   'modularity': 0.6772773403134748,
#   'average_clustering': 0.4296217795741152,
#   'percent_cross_category_edges': 92.96636085626912},
#  {'average_degree': 12.330097087378642,
#   'average_weighted_degree': 1249.3592233009708,
#   'average_path_length': 2.229963830192271,
#   'network_diameter': 5,
#   'graph_density': 0.12088330477822197,
#   'modularity': 0.7149018971592909,
#   'average_clustering': 0.4086578597219949,
#   'percent_cross_category_edges': 93.38582677165354},
#  {'average_degree': 12.194174757281553,
#   'average_weighted_degree': 1317.7087378640776,
#   'average_path_length': 2.2798400913763563,
#   'network_diameter': 5,
#   'graph_density': 0.11955073291452503,
#   'modularity': 0.7510855486383339,
#   'average_clustering': 0.3389329823167163,
#   'percent_cross_category_edges': 91.71974522292994},
#  {'average_degree': 12.097087378640778,
#   'average_weighted_degree': 1325.8640776699028,
#   'average_path_length': 2.2377688939653533,
#   'network_diameter': 4,
#   'graph_density': 0.11859889586902722,
#   'modularity': 0.7039415925157081,
#   'average_clustering': 0.379450811007297,
#   'percent_cross_category_edges': 92.776886035313},
#  {'average_degree': 13.087378640776699,
#   'average_weighted_degree': 1390.6796116504854,
#   'average_path_length': 2.2328193413287645,
#   'network_diameter': 5,
#   'graph_density': 0.1283076337331049,
#   'modularity': 0.641615172747258,
#   'average_clustering': 0.45330845313719836,
#   'percent_cross_category_edges': 91.3946587537092},
#  {'average_degree': 12.446601941747574,
#   'average_weighted_degree': 1351.0485436893205,
#   'average_path_length': 2.238720731010851,
#   'network_diameter': 5,
#   'graph_density': 0.12202550923281934,
#   'modularity': 0.6504420048519577,
#   'average_clustering': 0.3734449389124573,
#   'percent_cross_category_edges': 91.41965678627145},
#  {'average_degree': 12.271844660194175,
#   'average_weighted_degree': 1197.2038834951456,
#   'average_path_length': 2.2406244051018467,
#   'network_diameter': 5,
#   'graph_density': 0.12031220255092329,
#   'modularity': 0.6248028164075436,
#   'average_clustering': 0.4206243830249823,
#   'percent_cross_category_edges': 92.08860759493672},
#  {'average_degree': 11.805825242718447,
#   'average_weighted_degree': 1200.7378640776699,
#   'average_path_length': 2.2632781267846944,
#   'network_diameter': 5,
#   'graph_density': 0.11574338473253379,
#   'modularity': 0.6106318798855581,
#   'average_clustering': 0.3732647604184776,
#   'percent_cross_category_edges': 91.94078947368422},
#  {'average_degree': 12.815533980582524,
#   'average_weighted_degree': 1366.7961165048544,
#   'average_path_length': 2.2385303636017513,
#   'network_diameter': 6,
#   'graph_density': 0.125642490005711,
# ...
#   'percent_cross_category_edges': 93.93939393939394},
#  {'average_degree': 12.58252427184466,
#   'average_weighted_degree': 1371.5728155339805,
#   'average_path_length': 2.2122596611460117,
#   'network_diameter': 4,
#   'graph_density': 0.12335808109651628,
#   'modularity': 0.6841469537814456,
#   'average_clustering': 0.3893762749144738,
#   'percent_cross_category_edges': 92.74691358024691},
#  {'average_degree': 12.990291262135923,
#   'average_weighted_degree': 1390.621359223301,
#   'average_path_length': 2.221397296782791,
#   'network_diameter': 5,
#   'graph_density': 0.12735579668760708,
#   'modularity': 0.6577927456691893,
#   'average_clustering': 0.4413875942944666,
#   'percent_cross_category_edges': 92.67563527653215},
#  {'average_degree': 12.446601941747574,
#   'average_weighted_degree': 1320.9514563106795,
#   'average_path_length': 2.225204644964782,
#   'network_diameter': 5,
#   'graph_density': 0.12202550923281934,
#   'modularity': 0.6913156365123584,
#   'average_clustering': 0.4023336086569288,
#   'percent_cross_category_edges': 91.88767550702028},
#  {'average_degree': 12.485436893203884,
#   'average_weighted_degree': 1381.8640776699028,
#   'average_path_length': 2.191699980963259,
#   'network_diameter': 5,
#   'graph_density': 0.12240624405101846,
#   'modularity': 0.6313736034099199,
#   'average_clustering': 0.39041459120910066,
#   'percent_cross_category_edges': 92.2239502332815},
#  {'average_degree': 12.737864077669903,
#   'average_weighted_degree': 1321.009708737864,
#   'average_path_length': 2.216067009328003,
#   'network_diameter': 5,
#   'graph_density': 0.12488102036931277,
#   'modularity': 0.701643687972925,
#   'average_clustering': 0.35214936605278285,
#   'percent_cross_category_edges': 93.14024390243902},
#  {'average_degree': 12.718446601941748,
#   'average_weighted_degree': 1373.2621359223301,
#   'average_path_length': 2.2288216257376736,
#   'network_diameter': 5,
#   'graph_density': 0.12469065296021321,
#   'modularity': 0.680589507585607,
#   'average_clustering': 0.3716389881053795,
#   'percent_cross_category_edges': 92.21374045801527},
#  {'average_degree': 13.20388349514563,
#   'average_weighted_degree': 1391.4368932038835,
#   'average_path_length': 2.1802779364172853,
#   'network_diameter': 4,
#   'graph_density': 0.12944983818770225,
#   'modularity': 0.6932957076213077,
#   'average_clustering': 0.41589464459024617,
#   'percent_cross_category_edges': 93.08823529411765},
#  {'average_degree': 12.815533980582524,
#   'average_weighted_degree': 1382.1747572815534,
#   'average_path_length': 2.176660955644394,
#   'network_diameter': 5,
#   'graph_density': 0.125642490005711,
#   'modularity': 0.6719485972677793,
#   'average_clustering': 0.4288949025059739,
#   'percent_cross_category_edges': 91.21212121212122},
#  {'average_degree': 12.25242718446602,
#   'average_weighted_degree': 1335.514563106796,
#   'average_path_length': 2.255663430420712,
#   'network_diameter': 5,
#   'graph_density': 0.12012183514182372,
#   'modularity': 0.6248554193479812,
#   'average_clustering': 0.44660172028053247,
#   'percent_cross_category_edges': 91.60063391442155},
#  {'average_degree': 12.893203883495145,
#   'average_weighted_degree': 1374.2718446601941,
#   'average_path_length': 2.2198743575099944,
#   'network_diameter': 5,
#   'graph_density': 0.12640395964210926,
#   'modularity': 0.6929410294088473,
#   'average_clustering': 0.4217064936873911,
#   'percent_cross_category_edges': 93.22289156626506},
#  {'average_degree': 12.466019417475728,
#   'average_weighted_degree': 1334.7961165048544,
#   'average_path_length': 2.2181610508280984,
#   'network_diameter': 5,
#   'graph_density': 0.12221587664191891,
#   'modularity': 0.6396693046577271,
#   'average_clustering': 0.4196709078133938,
#   'percent_cross_category_edges': 91.74454828660437},
#  {'average_degree': 13.048543689320388,
#   'average_weighted_degree': 1390.6019417475727,
#   'average_path_length': 2.1956976965543498,
#   'network_diameter': 4,
#   'graph_density': 0.12792689891490577,
#   'modularity': 0.6396465810414768,
#   'average_clustering': 0.41324471686231284,
#   'percent_cross_category_edges': 93.00595238095238},
#  {'average_degree': 13.16504854368932,
#   'average_weighted_degree': 1391.3980582524273,
#   'average_path_length': 2.180468303826385,
#   'network_diameter': 5,
#   'graph_density': 0.12906910336950314,
#   'modularity': 0.6704256826594865,
#   'average_clustering': 0.40925031705924475,
#   'percent_cross_category_edges': 92.62536873156341},
#  {'average_degree': 12.310679611650485,
#   'average_weighted_degree': 1275.8058252427184,
#   'average_path_length': 2.2172092137826005,
#   'network_diameter': 4,
#   'graph_density': 0.1206929373691224,
#   'modularity': 0.7026718621904563,
#   'average_clustering': 0.36784558654618926,
#   'percent_cross_category_edges': 92.58675078864354},
#  {'average_degree': 12.660194174757281,
#   'average_weighted_degree': 1360.7572815533981,
#   'average_path_length': 2.2103559870550162,
#   'network_diameter': 4,
#   'graph_density': 0.12411955073291453,
#   'modularity': 0.6571544152788389,
#   'average_clustering': 0.3919062713926387,
#   'percent_cross_category_edges': 92.79141104294479},
#  {'average_degree': 12.776699029126213,
#   'average_weighted_degree': 1383.3398058252428,
#   'average_path_length': 2.187321530553969,
#   'network_diameter': 4,
#   'graph_density': 0.1252617551875119,
#   'modularity': 0.6485162139693715,
#   'average_clustering': 0.4387498956053236,
#   'percent_cross_category_edges': 92.09726443768997},
#  {'average_degree': 12.660194174757281,
#   'average_weighted_degree': 1285.2427184466019,
#   'average_path_length': 2.193222920236056,
#   'network_diameter': 4,
#   'graph_density': 0.12411955073291453,
#   'modularity': 0.6140754628712076,
#   'average_clustering': 0.4355109263422122,
#   'percent_cross_category_edges': 92.79141104294479},
#  {'average_degree': 12.155339805825243,
#   'average_weighted_degree': 1236.7378640776699,
#   'average_path_length': 2.249190938511327,
#   'network_diameter': 4,
#   'graph_density': 0.1191699980963259,
#   'modularity': 0.6976792718424494,
#   'average_clustering': 0.40596224444719076,
#   'percent_cross_category_edges': 92.17252396166134},
#  {'average_degree': 12.135922330097088,
#   'average_weighted_degree': 1295.0291262135922,
#   'average_path_length': 2.2400533028745477,
#   'network_diameter': 4,
#   'graph_density': 0.11897963068722635,
#   'modularity': 0.7332876843581666,
#   'average_clustering': 0.3455084912394195,
#   'percent_cross_category_edges': 92.47999999999999},
#  {'average_degree': 12.233009708737864,
#   'average_weighted_degree': 1361.2038834951456,
#   'average_path_length': 2.230915667237769,
#   'network_diameter': 4,
#   'graph_density': 0.11993146773272416,
#   'modularity': 0.686633253755917,
#   'average_clustering': 0.3493343042739931,
#   'percent_cross_category_edges': 90.15873015873017},
#  {'average_degree': 12.83495145631068,
#   'average_weighted_degree': 1380.8349514563106,
#   'average_path_length': 2.2274890538739767,
#   'network_diameter': 4,
#   'graph_density': 0.1258328574148106,
#   'modularity': 0.6367774145200962,
#   'average_clustering': 0.36425185434041263,
#   'percent_cross_category_edges': 92.28441754916793},
#  {'average_degree': 12.62135922330097,
#   'average_weighted_degree': 1326.5242718446602,
#   'average_path_length': 2.173424709689701,
#   'network_diameter': 4,
#   'graph_density': 0.1237388159147154,
#   'modularity': 0.6616778066784437,
#   'average_clustering': 0.42787471363656376,
#   'percent_cross_category_edges': 91.23076923076923},
#  {'average_degree': 12.194174757281553,
#   'average_weighted_degree': 1371.6699029126214,
#   'average_path_length': 2.247477631829431,
#   'network_diameter': 5,
#   'graph_density': 0.11955073291452503,
#   'modularity': 0.6730485504532383,
#   'average_clustering': 0.41481350420962576,
#   'percent_cross_category_edges': 91.56050955414013},
#  {'average_degree': 12.368932038834952,
#   'average_weighted_degree': 1204.2330097087379,
#   'average_path_length': 2.217780316009899,
#   'network_diameter': 4,
#   'graph_density': 0.1212640395964211,
#   'modularity': 0.7120657973285756,
#   'average_clustering': 0.37553859691690417,
#   'percent_cross_category_edges': 91.83673469387756},
#  {'average_degree': 12.699029126213592,
#   'average_weighted_degree': 1374.9514563106795,
#   'average_path_length': 2.177993527508091,
#   'network_diameter': 4,
#   'graph_density': 0.12450028555111364,
#   'modularity': 0.6956061255477377,
#   'average_clustering': 0.38356473336056374,
#   'percent_cross_category_edges': 92.20183486238533},
#  {'average_degree': 12.854368932038835,
#   'average_weighted_degree': 1385.4757281553398,
#   'average_path_length': 2.2320578716923665,
#   'network_diameter': 5,
#   'graph_density': 0.12602322482391015,
#   'modularity': 0.6772672676591536,
#   'average_clustering': 0.42862284292840197,
#   'percent_cross_category_edges': 92.74924471299094},
#  {'average_degree': 13.45631067961165,
#   'average_weighted_degree': 1391.6893203883494,
#   'average_path_length': 2.1557205406434417,
#   'network_diameter': 4,
#   'graph_density': 0.13192461450599657,
#   'modularity': 0.5645529532645968,
#   'average_clustering': 0.45969100649444894,
#   'percent_cross_category_edges': 92.06349206349206},
#  {'average_degree': 12.699029126213592,
#   'average_weighted_degree': 1384.2135922330096,
#   'average_path_length': 2.161241195507329,
#   'network_diameter': 4,
#   'graph_density': 0.12450028555111364,
#   'modularity': 0.680132378933746,
#   'average_clustering': 0.4152589223569515,
#   'percent_cross_category_edges': 91.43730886850153},
#  {'average_degree': 12.504854368932039,
#   'average_weighted_degree': 1209.2233009708739,
#   'average_path_length': 2.227869788692176,
#   'network_diameter': 5,
#   'graph_density': 0.12259661146011802,
#   'modularity': 0.6380729126984804,
#   'average_clustering': 0.3631655555831762,
#   'percent_cross_category_edges': 92.54658385093167},
#  {'average_degree': 13.262135922330097,
#   'average_weighted_degree': 1391.495145631068,
#   'average_path_length': 2.155530173234342,
#   'network_diameter': 4,
#   'graph_density': 0.13002094041500095,
#   'modularity': 0.6871136916441193,
#   'average_clustering': 0.40499867742275975,
#   'percent_cross_category_edges': 93.26500732064422},
#  {'average_degree': 12.524271844660195,
#   'average_weighted_degree': 1353.7087378640776,
#   'average_path_length': 2.178754997144489,
#   'network_diameter': 4,
#   'graph_density': 0.12278697886921759,
#   'modularity': 0.6629170518867922,
#   'average_clustering': 0.4349888494106589,
#   'percent_cross_category_edges': 91.7829457364341},
#  {'average_degree': 12.737864077669903,
#   'average_weighted_degree': 1345.2038834951456,
#   'average_path_length': 2.1854178564629736,
#   'network_diameter': 4,
#   'graph_density': 0.12488102036931277,
#   'modularity': 0.6944133268408998,
#   'average_clustering': 0.3893945118573745,
#   'percent_cross_category_edges': 92.22560975609755},
#  {'average_degree': 12.660194174757281,
#   'average_weighted_degree': 1318.8543689320388,
#   'average_path_length': 2.2175899486007995,
#   'network_diameter': 5,
#   'graph_density': 0.12411955073291453,
#   'modularity': 0.6955334943856273,
#   'average_clustering': 0.37311291250877476,
#   'percent_cross_category_edges': 92.17791411042946},
#  {'average_degree': 12.29126213592233,
#   'average_weighted_degree': 1361.3592233009708,
#   'average_path_length': 2.226537216828479,
#   'network_diameter': 5,
#   'graph_density': 0.12050256996002284,
#   'modularity': 0.7138461656144761,
#   'average_clustering': 0.4336859257202521,
#   'percent_cross_category_edges': 91.15323854660348},
#  {'average_degree': 13.12621359223301,
#   'average_weighted_degree': 1391.3592233009708,
#   'average_path_length': 2.1719017704169046,
#   'network_diameter': 4,
#   'graph_density': 0.12868836855130403,
#   'modularity': 0.6854467046670205,
#   'average_clustering': 0.4200602786038673,
#   'percent_cross_category_edges': 90.08875739644971},
#  {'average_degree': 12.368932038834952,
#   'average_weighted_degree': 1233.9611650485438,
#   'average_path_length': 2.2261564820102797,
#   'network_diameter': 4,
#   'graph_density': 0.1212640395964211,
#   'modularity': 0.7046272828095901,
#   'average_clustering': 0.38066992897704666,
#   'percent_cross_category_edges': 90.58084772370488},
#  {'average_degree': 12.58252427184466,
#   'average_weighted_degree': 1372.3106796116506,
#   'average_path_length': 2.1928421854178564,
#   'network_diameter': 5,
#   'graph_density': 0.12335808109651628,
#   'modularity': 0.7263440535581588,
#   'average_clustering': 0.3899181544357605,
#   'percent_cross_category_edges': 93.51851851851852},
#  {'average_degree': 12.135922330097088,
#   'average_weighted_degree': 1311.1456310679612,
#   'average_path_length': 2.2248239101465828,
#   'network_diameter': 4,
#   'graph_density': 0.11897963068722635,
#   'modularity': 0.7079645482745702,
#   'average_clustering': 0.390334229247699,
#   'percent_cross_category_edges': 92.16},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1308.2135922330096,
#   'average_path_length': 2.2189225204644965,
#   'network_diameter': 5,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6708985770491872,
#   'average_clustering': 0.4315843447662153,
#   'percent_cross_category_edges': 92.6040061633282},
#  {'average_degree': 12.174757281553399,
#   'average_weighted_degree': 1341.495145631068,
#   'average_path_length': 2.185227489053874,
#   'network_diameter': 5,
#   'graph_density': 0.11936036550542548,
#   'modularity': 0.6467743102701412,
#   'average_clustering': 0.3948319748501286,
#   'percent_cross_category_edges': 92.82296650717703},
#  {'average_degree': 11.74757281553398,
#   'average_weighted_degree': 1247.2815533980583,
#   'average_path_length': 2.245193222920236,
#   'network_diameter': 5,
#   'graph_density': 0.1151722825052351,
#   'modularity': 0.7185003136924578,
#   'average_clustering': 0.4289727245325297,
#   'percent_cross_category_edges': 92.39669421487604},
#  {'average_degree': 13.029126213592233,
#   'average_weighted_degree': 1382.7378640776699,
#   'average_path_length': 2.2139729678279076,
#   'network_diameter': 5,
#   'graph_density': 0.12773653150580622,
#   'modularity': 0.6982355369367114,
#   'average_clustering': 0.3959061877265137,
#   'percent_cross_category_edges': 92.69746646795826},
#  {'average_degree': 12.912621359223301,
#   'average_weighted_degree': 1344.6407766990292,
#   'average_path_length': 2.194365124690653,
#   'network_diameter': 4,
#   'graph_density': 0.12659432705120882,
#   'modularity': 0.674662074266079,
#   'average_clustering': 0.4229347723927816,
#   'percent_cross_category_edges': 93.6842105263158},
#  {'average_degree': 12.932038834951456,
#   'average_weighted_degree': 1383.4368932038835,
#   'average_path_length': 2.17837426232629,
#   'network_diameter': 4,
#   'graph_density': 0.1267846944603084,
#   'modularity': 0.646089069673127,
#   'average_clustering': 0.4319118567106192,
#   'percent_cross_category_edges': 92.94294294294293},
#  {'average_degree': 12.407766990291263,
#   'average_weighted_degree': 1321.6893203883494,
#   'average_path_length': 2.2524271844660193,
#   'network_diameter': 4,
#   'graph_density': 0.12164477441462021,
#   'modularity': 0.6274594832446053,
#   'average_clustering': 0.3693842851713328,
#   'percent_cross_category_edges': 91.8622848200313},
#  {'average_degree': 12.640776699029127,
#   'average_weighted_degree': 1348.3300970873786,
#   'average_path_length': 2.204835332191129,
#   'network_diameter': 4,
#   'graph_density': 0.12392918332381496,
#   'modularity': 0.6883992271649723,
#   'average_clustering': 0.4211621361486821,
#   'percent_cross_category_edges': 92.31950844854072},
#  {'average_degree': 12.757281553398059,
#   'average_weighted_degree': 1388.0194174757282,
#   'average_path_length': 2.229011993146773,
#   'network_diameter': 5,
#   'graph_density': 0.12507138777841234,
#   'modularity': 0.6166417053697102,
#   'average_clustering': 0.4026092508327094,
#   'percent_cross_category_edges': 92.69406392694064},
#  {'average_degree': 12.640776699029127,
#   'average_weighted_degree': 1364.8349514563106,
#   'average_path_length': 2.208452312964021,
#   'network_diameter': 4,
#   'graph_density': 0.12392918332381496,
#   'modularity': 0.7166269490291572,
#   'average_clustering': 0.3799389665642454,
#   'percent_cross_category_edges': 92.93394777265746},
#  ...]

# %%
# Print results
for metric, stats in results.items():
    print(f"{metric.capitalize().replace('_', ' ')}:")
    print(f"  Female Original Value: {f_original_metrics[metric]:.4f}")
    print(f"  Male Original Value: {m_original_metrics[metric]:.4f}")
    print(f"  Random Average: {statistics.mean(rd_metric[metric] for rd_metric in random_metrics):.4f}")
    print(f"  Random Standard Deviation: {statistics.stdev(rd_metric[metric] for rd_metric in random_metrics):.4f}")
    print(f"  T-Statistic: {stats['t_stat']:.4f}" if stats['t_stat'] is not None else "  T-Statistic: N/A")
    print(f"  P-Value: {stats['p_value']:.4f}" if stats['p_value'] is not None else "  P-Value: N/A")
    if stats["p_value"] is not None:
        if stats["p_value"] < 0.05:
            print("  Significant difference detected.")
        else:
            print("  No significant difference detected.")
    print("-" * 50)
# Out:
# Average degree:
#   Female Original Value: 13.1262
#   Male Original Value: 11.6117
#   Random Average: 11.9598
#   Random Standard Deviation: 0.7284
#   T-Statistic: -1532.6272
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Average weighted degree:
#   Female Original Value: 1391.3592
#   Male Original Value: 904.4466
#   Random Average: 1106.3587
#   Random Standard Deviation: 230.5870
#   T-Statistic: -1569.5479
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Average path length:
#   Female Original Value: 2.1611
#   Male Original Value: 2.3503
#   Random Average: 2.2568
#   Random Standard Deviation: 0.0575
#   T-Statistic: 3020.4514
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Network diameter:
#   Female Original Value: 4.0000
#   Male Original Value: 6.0000
#   Random Average: 4.6800
#   Random Standard Deviation: 0.5699
#   T-Statistic: 3262.6454
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Graph density:
#   Female Original Value: 0.1287
#   Male Original Value: 0.1138
#   Random Average: 0.1173
#   Random Standard Deviation: 0.0071
#   T-Statistic: -1532.6272
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Modularity:
#   Female Original Value: 0.1312
#   Male Original Value: 0.2390
#   Random Average: 0.6228
#   Random Standard Deviation: 0.0574
#   T-Statistic: 3475.4339
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Average clustering:
#   Female Original Value: 0.4814
#   Male Original Value: 0.3980
#   Random Average: 0.3816
#   Random Standard Deviation: 0.0353
#   T-Statistic: -1931.6741
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Percent cross category edges:
#   Female Original Value: 89.3491
#   Male Original Value: 88.1271
#   Random Average: 92.3509
#   Random Standard Deviation: 0.8548
#   T-Statistic: -1646.2335
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------

# %% [markdown]
# # Save out clusters from Louvain cluster

# %%
random.seed(123)

# %%
# Modularity (using Louvain method)
def get_louvain_clusters(graph, node_categories):
    partition = community_louvain.best_partition(graph)
    communities = {}
    for node, comm_id in partition.items():
        communities.setdefault(comm_id, set()).add(node)
    
    # Convert the dictionary into a list of tuples (node, cluster)
    data = [(node, cluster) for cluster, nodes in communities.items() for node in nodes]

    # Create a pandas DataFrame
    df = pd.DataFrame(data, columns=["Node", "Cluster"])
    df['disease_category'] = df['Node'].map(node_categories)
    return df

# %%
clusters_f = get_louvain_clusters(G_f, node_categories)
clusters_m = get_louvain_clusters(G_m, node_categories)

# %%
clusters_f.to_csv("/Users/vsriram/Desktop/G_f_clusters.csv", index=False)
clusters_m.to_csv("/Users/vsriram/Desktop/G_m_clusters.csv", index=False)
