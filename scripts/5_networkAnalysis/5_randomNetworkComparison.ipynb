# %% [markdown]
# ## Import statements

# %%
# Import required packages
import pandas as pd
import networkx as nx
import random
from scipy.stats import ttest_1samp
from networkx.algorithms.community import modularity
import community.community_louvain as community_louvain
from itertools import combinations
import statistics

random.seed(123)

# %% [markdown]
# ## Function definitions

# %%
# Function to generate random networks
def generate_random_weighted_network_with_expected_degree(degree_seq, original_weights, original_node_labels):
    while True:
        # Generate a random network with the expected degree distribution
        randomized_graph = nx.expected_degree_graph(degree_seq, selfloops=False)

        if nx.is_connected(randomized_graph):
            # Reassign original node labels
            mapping = {old_label: new_label for old_label, new_label in zip(randomized_graph.nodes(), original_node_labels)}
            randomized_graph = nx.relabel_nodes(randomized_graph, mapping)

            # Reassign weights randomly to the edges
            randomized_weights = random.sample(original_weights, len(original_weights))
            for (u, v), weight in zip(randomized_graph.edges(), randomized_weights):
                randomized_graph[u][v]["weight"] = weight
            
            return randomized_graph

# %%
# Function to compute various metrics for a graph
def compute_graph_metrics(graph, node_category_dict):
    metrics = {}
    
    # Average degree
    metrics["average_degree"] = sum(dict(graph.degree()).values()) / len(graph)
    
    # Average weighted degree
    metrics["average_weighted_degree"] = sum(dict(graph.degree(weight="weight")).values()) / len(graph)

    # Average path length (only if graph is connected)
    if nx.is_connected(graph):
        metrics["average_path_length"] = nx.average_shortest_path_length(graph)
        metrics["network_diameter"] = nx.diameter(graph)
        
    # Graph density
    metrics["graph_density"] = nx.density(graph)
    
    # Modularity (using Louvain method)
    partition = community_louvain.best_partition(graph)
    communities = {}
    for node, comm_id in partition.items():
        communities.setdefault(comm_id, set()).add(node)
    modularity_communities = list(communities.values())
    metrics["modularity"] = modularity(graph, modularity_communities)
    
    # Average clustering coefficient
    metrics["average_clustering"] = nx.average_clustering(graph)

    # Percent of cross-category edges
    num_cc_edges = 0
    for edge in graph.edges:
        first_node = edge[0]
        second_node = edge[1]
        first_category = node_category_dict[first_node]
        second_category = node_category_dict[second_node]
        if first_category != second_category:
            num_cc_edges += 1
    metrics["percent_cross_category_edges"] = num_cc_edges/len(graph.edges)*100

    return metrics

# %%
# Function to perform a t-test; is the difference between the male and female network
#  significantly different from differences in a random population?
def perform_statistical_analysis(original_value_f, original_value_m, random_values):
    original_difference = original_value_f - original_value_m

    random_differences = [rv1 - rv2 for rv1, rv2 in combinations(random_values, 2)]

    t_stat, p_value = ttest_1samp(random_differences, original_difference)
    
    return {
        "original_difference": original_difference,
        "t_stat": t_stat,
        "p_value": p_value,
    }

# %% [markdown]
# ## Perform analysis

# %%
# Node map
node_categories_path = "/Users/vsriram/Desktop/GxS/ddnComp_personalComputer/traitDescription_diseaseCategories.csv"
node_categories = pd.read_csv(node_categories_path, sep=",")[['Id', 'Disease Category']].set_index('Id')['Disease Category'].to_dict()

# %%
# Import male and female networks
f_file_path = "/Users/vsriram/Desktop/GxS/ddnComp_personalComputer/ddnsForDDNComp/ssDDNneg4_femaleBlock_edgeMap.tsv"
f_edges_df = pd.read_csv(f_file_path, sep="\t").iloc[:, :3]
f_edges_df['Weight'] = pd.to_numeric(f_edges_df['Weight'], errors='coerce')

m_file_path = "/Users/vsriram/Desktop/GxS/ddnComp_personalComputer/ddnsForDDNComp/ssDDNneg4_maleBlock_edgeMap.tsv"
m_edges_df = pd.read_csv(m_file_path, sep="\t").iloc[:, :3]
m_edges_df['Weight'] = pd.to_numeric(m_edges_df['Weight'], errors='coerce')

# %%
f_node_labels = list(set(f_edges_df['Source']).union(set(f_edges_df['Target'])))
m_node_labels = list(set(m_edges_df['Source']).union(set(m_edges_df['Target'])))

# %%
# Create the original graphs
G_f = nx.Graph()
G_f.add_weighted_edges_from(f_edges_df.values)

G_m = nx.Graph()
G_m.add_weighted_edges_from(m_edges_df.values)

# %%
# Compute the degree sequences
f_degree_sequence = [d for n, d in G_f.degree()]
m_degree_sequence = [d for n, d in G_m.degree()]

# %%
# Extract edge weights
f_original_weights = [d["weight"] for _, _, d in G_f.edges(data=True)]
m_original_weights = [d["weight"] for _, _, d in G_m.edges(data=True)]

# %%
# Generate 50 random networks per sex
num_random_networks = 50

f_random_networks = [
    generate_random_weighted_network_with_expected_degree(f_degree_sequence, f_original_weights, f_node_labels)
    for _ in range(num_random_networks)
]

# %%
m_random_networks = [
    generate_random_weighted_network_with_expected_degree(m_degree_sequence, m_original_weights, m_node_labels)
    for _ in range(num_random_networks)
]

random_networks = f_random_networks + m_random_networks

# %%
# Compute metrics for the original graphs
f_original_metrics = compute_graph_metrics(G_f, node_categories)
m_original_metrics = compute_graph_metrics(G_m, node_categories)

# %%
# Compute metrics for each random network
random_metrics = [compute_graph_metrics(net, node_categories) for net in random_networks]

# %%
# Perform t-tests for each metric
results = {}
for metric in f_original_metrics.keys():
    random_values = [rm[metric] for rm in random_metrics]
    results[metric] = perform_statistical_analysis(f_original_metrics[metric], m_original_metrics[metric], random_values)

# %%
random_metrics
# Out:
# [{'average_degree': 12.718446601941748,
#   'average_weighted_degree': 1372.6019417475727,
#   'average_path_length': 2.187321530553969,
#   'network_diameter': 4,
#   'graph_density': 0.12469065296021321,
#   'modularity': 0.6666878497530807,
#   'average_clustering': 0.4071671728122718,
#   'percent_cross_category_edges': 93.74045801526718},
#  {'average_degree': 12.79611650485437,
#   'average_weighted_degree': 1333.2427184466019,
#   'average_path_length': 2.2381496287835523,
#   'network_diameter': 5,
#   'graph_density': 0.12545212259661145,
#   'modularity': 0.6379745889430202,
#   'average_clustering': 0.4132179413200597,
#   'percent_cross_category_edges': 95.75113808801214},
#  {'average_degree': 11.728155339805825,
#   'average_weighted_degree': 1244.2718446601941,
#   'average_path_length': 2.286502950694841,
#   'network_diameter': 5,
#   'graph_density': 0.11498191509613555,
#   'modularity': 0.6841710537633592,
#   'average_clustering': 0.3730781253290286,
#   'percent_cross_category_edges': 95.19867549668875},
#  {'average_degree': 12.524271844660195,
#   'average_weighted_degree': 1246.5631067961165,
#   'average_path_length': 2.2225395012373883,
#   'network_diameter': 4,
#   'graph_density': 0.12278697886921759,
#   'modularity': 0.6323319651447776,
#   'average_clustering': 0.3488994661239261,
#   'percent_cross_category_edges': 94.88372093023256},
#  {'average_degree': 12.21359223300971,
#   'average_weighted_degree': 1232.1747572815534,
#   'average_path_length': 2.2516657148296213,
#   'network_diameter': 5,
#   'graph_density': 0.11974110032362459,
#   'modularity': 0.6833567581945202,
#   'average_clustering': 0.3781398476864441,
#   'percent_cross_category_edges': 94.4356120826709},
#  {'average_degree': 12.019417475728156,
#   'average_weighted_degree': 1255.8640776699028,
#   'average_path_length': 2.2497620407386254,
#   'network_diameter': 4,
#   'graph_density': 0.11783742623262898,
#   'modularity': 0.6993739094621815,
#   'average_clustering': 0.40516413614620556,
#   'percent_cross_category_edges': 95.15347334410339},
#  {'average_degree': 12.407766990291263,
#   'average_weighted_degree': 1289.3009708737864,
#   'average_path_length': 2.2364363221016563,
#   'network_diameter': 5,
#   'graph_density': 0.12164477441462021,
#   'modularity': 0.6352848219736793,
#   'average_clustering': 0.3510591979666199,
#   'percent_cross_category_edges': 93.27073552425665},
#  {'average_degree': 13.436893203883495,
#   'average_weighted_degree': 1391.6699029126214,
#   'average_path_length': 2.14791547687036,
#   'network_diameter': 4,
#   'graph_density': 0.13173424709689702,
#   'modularity': 0.6842592134636437,
#   'average_clustering': 0.4508238803726138,
#   'percent_cross_category_edges': 93.78612716763006},
#  {'average_degree': 12.62135922330097,
#   'average_weighted_degree': 1313.3592233009708,
#   'average_path_length': 2.184656386826575,
#   'network_diameter': 5,
#   'graph_density': 0.1237388159147154,
#   'modularity': 0.7254760448436247,
#   'average_clustering': 0.42345965541772723,
#   'percent_cross_category_edges': 93.53846153846153},
#  {'average_degree': 12.757281553398059,
#   'average_weighted_degree': 1318.7572815533981,
#   'average_path_length': 2.1945554920997523,
#   'network_diameter': 5,
#   'graph_density': 0.12507138777841234,
#   'modularity': 0.6960339654640574,
#   'average_clustering': 0.41497357418206576,
#   'percent_cross_category_edges': 95.12937595129375},
#  {'average_degree': 12.640776699029127,
#   'average_weighted_degree': 1376.504854368932,
#   'average_path_length': 2.203502760327432,
#   'network_diameter': 4,
#   'graph_density': 0.12392918332381496,
#   'modularity': 0.6279825401086614,
#   'average_clustering': 0.38307966784275227,
#   'percent_cross_category_edges': 94.00921658986175},
#  {'average_degree': 12.271844660194175,
#   'average_weighted_degree': 1190.5242718446602,
#   'average_path_length': 2.2585189415572056,
#   'network_diameter': 6,
#   'graph_density': 0.12031220255092329,
#   'modularity': 0.6834773852154189,
#   'average_clustering': 0.3736768038554408,
#   'percent_cross_category_edges': 93.0379746835443},
#  {'average_degree': 12.446601941747574,
#   'average_weighted_degree': 1313.0873786407767,
#   'average_path_length': 2.197411003236246,
#   'network_diameter': 4,
#   'graph_density': 0.12202550923281934,
#   'modularity': 0.6863896824773819,
#   'average_clustering': 0.46787556858992835,
#   'percent_cross_category_edges': 92.97971918876755},
#  {'average_degree': 12.660194174757281,
#   'average_weighted_degree': 1311.611650485437,
#   'average_path_length': 2.1650485436893203,
#   'network_diameter': 4,
#   'graph_density': 0.12411955073291453,
#   'modularity': 0.655239516874361,
#   'average_clustering': 0.40790415004645303,
#   'percent_cross_category_edges': 93.55828220858896},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1318.5436893203882,
#   'average_path_length': 2.217780316009899,
#   'network_diameter': 5,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6263494353158796,
#   'average_clustering': 0.43705873664244216,
#   'percent_cross_category_edges': 93.68258859784284},
#  {'average_degree': 12.504854368932039,
#   'average_weighted_degree': 1354.2135922330096,
#   'average_path_length': 2.206167904054826,
#   'network_diameter': 4,
#   'graph_density': 0.12259661146011802,
#   'modularity': 0.5961866659808148,
#   'average_clustering': 0.39996549700602346,
#   'percent_cross_category_edges': 94.87577639751554},
#  {'average_degree': 12.135922330097088,
#   'average_weighted_degree': 1348.116504854369,
#   'average_path_length': 2.2059775366457264,
#   'network_diameter': 4,
#   'graph_density': 0.11897963068722635,
#   'modularity': 0.7263430033466931,
#   'average_clustering': 0.3894212406159932,
#   'percent_cross_category_edges': 94.56},
#  {'average_degree': 12.330097087378642,
#   'average_weighted_degree': 1326.3106796116506,
#   'average_path_length': 2.2545212259661147,
#   'network_diameter': 4,
#   'graph_density': 0.12088330477822197,
#   'modularity': 0.6683639463557641,
#   'average_clustering': 0.4088144652557829,
#   'percent_cross_category_edges': 93.85826771653544},
#  {'average_degree': 12.25242718446602,
#   'average_weighted_degree': 1334.3495145631068,
#   'average_path_length': 2.2516657148296213,
#   'network_diameter': 4,
#   'graph_density': 0.12012183514182372,
#   'modularity': 0.7075909774908563,
#   'average_clustering': 0.38840310421083085,
#   'percent_cross_category_edges': 93.6608557844691},
#  {'average_degree': 12.679611650485437,
#   'average_weighted_degree': 1375.9029126213593,
#   'average_path_length': 2.2297734627831716,
#   'network_diameter': 5,
#   'graph_density': 0.12430991814201409,
#   'modularity': 0.723180543102882,
#   'average_clustering': 0.35145156725911875,
#   'percent_cross_category_edges': 93.87442572741195},
#  {'average_degree': 13.572815533980583,
#   'average_weighted_degree': 1391.8058252427184,
#   'average_path_length': 2.1728536074624025,
#   'network_diameter': 4,
#   'graph_density': 0.13306681896059394,
#   'modularity': 0.6245674140055664,
#   'average_clustering': 0.42619762845503206,
#   'percent_cross_category_edges': 93.84835479256081},
#  {'average_degree': 13.009708737864077,
#   'average_weighted_degree': 1380.2330097087379,
#   'average_path_length': 2.1696173615077097,
#   'network_diameter': 4,
#   'graph_density': 0.12754616409670663,
#   'modularity': 0.6382913393718287,
#   'average_clustering': 0.4217981528898168,
#   'percent_cross_category_edges': 95.3731343283582},
#  {'average_degree': 11.941747572815533,
#   'average_weighted_degree': 1332.7766990291261,
#   'average_path_length': 2.198172472872644,
#   'network_diameter': 4,
#   'graph_density': 0.11707595659623073,
#   'modularity': 0.6890887682329979,
#   'average_clustering': 0.3650860153985278,
#   'percent_cross_category_edges': 93.33333333333333},
#  {'average_degree': 12.62135922330097,
#   'average_weighted_degree': 1236.7572815533981,
#   'average_path_length': 2.1798972015990863,
#   'network_diameter': 4,
#   'graph_density': 0.1237388159147154,
#   'modularity': 0.6458729932270783,
#   'average_clustering': 0.3889012988893251,
#   'percent_cross_category_edges': 94.76923076923077},
#  {'average_degree': 11.864077669902912,
#   'average_weighted_degree': 1332.485436893204,
#   'average_path_length': 2.2562345326480107,
#   'network_diameter': 5,
#   'graph_density': 0.11631448695983247,
#   'modularity': 0.7023620469097164,
#   'average_clustering': 0.3872475170342411,
#   'percent_cross_category_edges': 94.10801963993454},
#  {'average_degree': 12.893203883495145,
#   'average_weighted_degree': 1375.514563106796,
#   'average_path_length': 2.23034456501047,
#   'network_diameter': 5,
#   'graph_density': 0.12640395964210926,
#   'modularity': 0.66917000189002,
#   'average_clustering': 0.4010103864854431,
#   'percent_cross_category_edges': 95.03012048192771},
#  {'average_degree': 12.427184466019417,
#   'average_weighted_degree': 1366.7378640776699,
#   'average_path_length': 2.1911288787359604,
#   'network_diameter': 5,
#   'graph_density': 0.12183514182371978,
#   'modularity': 0.7231184375163461,
#   'average_clustering': 0.39424328938174646,
#   'percent_cross_category_edges': 93.28125},
#  {'average_degree': 13.436893203883495,
#   'average_weighted_degree': 1391.6699029126214,
#   'average_path_length': 2.1467732724157624,
#   'network_diameter': 4,
#   'graph_density': 0.13173424709689702,
#   'modularity': 0.6573680909524363,
#   'average_clustering': 0.45067025542319983,
#   'percent_cross_category_edges': 94.36416184971098},
#  {'average_degree': 11.611650485436893,
#   'average_weighted_degree': 1330.5631067961165,
#   'average_path_length': 2.2354844850561584,
#   'network_diameter': 4,
#   'graph_density': 0.11383971064153817,
#   'modularity': 0.6996562661185983,
#   'average_clustering': 0.3800419548701113,
#   'percent_cross_category_edges': 94.14715719063545},
#  {'average_degree': 12.83495145631068,
#   'average_weighted_degree': 1328.0970873786407,
#   'average_path_length': 2.173424709689701,
#   'network_diameter': 4,
#   'graph_density': 0.1258328574148106,
#   'modularity': 0.6379306161475948,
#   'average_clustering': 0.443172421686871,
#   'percent_cross_category_edges': 93.19213313161876},
#  {'average_degree': 12.854368932038835,
#   'average_weighted_degree': 1385.6893203883494,
#   'average_path_length': 2.220826194555492,
#   'network_diameter': 4,
#   'graph_density': 0.12602322482391015,
#   'modularity': 0.6277455777705224,
#   'average_clustering': 0.38111003179143776,
#   'percent_cross_category_edges': 94.10876132930514},
#  {'average_degree': 13.553398058252426,
#   'average_weighted_degree': 1391.7864077669904,
#   'average_path_length': 2.1441081286883685,
#   'network_diameter': 4,
#   'graph_density': 0.13287645155149438,
#   'modularity': 0.6558397262236336,
#   'average_clustering': 0.4598041546857337,
#   'percent_cross_category_edges': 93.98280802292264},
#  {'average_degree': 11.883495145631068,
#   'average_weighted_degree': 1284.2135922330096,
#   'average_path_length': 2.2649914334665904,
#   'network_diameter': 5,
#   'graph_density': 0.11650485436893204,
#   'modularity': 0.7167325451790271,
#   'average_clustering': 0.35569250967531674,
#   'percent_cross_category_edges': 93.4640522875817},
#  {'average_degree': 12.990291262135923,
#   'average_weighted_degree': 1385.126213592233,
#   'average_path_length': 2.156101275461641,
#   'network_diameter': 4,
#   'graph_density': 0.12735579668760708,
#   'modularity': 0.6507142091674839,
#   'average_clustering': 0.45756985406797523,
#   'percent_cross_category_edges': 92.67563527653215},
#  {'average_degree': 12.640776699029127,
#   'average_weighted_degree': 1338.1941747572816,
#   'average_path_length': 2.205596801827527,
#   'network_diameter': 5,
#   'graph_density': 0.12392918332381496,
#   'modularity': 0.731751108414702,
#   'average_clustering': 0.4022499679808328,
#   'percent_cross_category_edges': 92.01228878648233},
#  {'average_degree': 12.62135922330097,
#   'average_weighted_degree': 1315.883495145631,
#   'average_path_length': 2.1966495335998477,
#   'network_diameter': 4,
#   'graph_density': 0.1237388159147154,
#   'modularity': 0.7115750283259985,
#   'average_clustering': 0.4256340609499673,
#   'percent_cross_category_edges': 93.84615384615384},
#  {'average_degree': 11.922330097087379,
#   'average_weighted_degree': 1235.009708737864,
#   'average_path_length': 2.2598515134209025,
#   'network_diameter': 4,
#   'graph_density': 0.11688558918713117,
#   'modularity': 0.6962189817873549,
#   'average_clustering': 0.3677270559463176,
#   'percent_cross_category_edges': 94.78827361563518},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1376.6601941747572,
#   'average_path_length': 2.207500475918523,
#   'network_diameter': 4,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6377318895508183,
#   'average_clustering': 0.36374351422330553,
#   'percent_cross_category_edges': 92.44992295839754},
#  {'average_degree': 12.174757281553399,
#   'average_weighted_degree': 1252.1359223300972,
#   'average_path_length': 2.286502950694841,
#   'network_diameter': 5,
#   'graph_density': 0.11936036550542548,
#   'modularity': 0.6206227945357365,
#   'average_clustering': 0.36457498146205713,
#   'percent_cross_category_edges': 93.46092503987241},
#  {'average_degree': 12.815533980582524,
#   'average_weighted_degree': 1386.6601941747572,
#   'average_path_length': 2.2090234151913193,
#   'network_diameter': 5,
#   'graph_density': 0.125642490005711,
#   'modularity': 0.6926141989049254,
#   'average_clustering': 0.4106967588008141,
#   'percent_cross_category_edges': 92.72727272727272},
#  {'average_degree': 12.058252427184467,
#   'average_weighted_degree': 1271.3980582524273,
#   'average_path_length': 2.2821245002855512,
#   'network_diameter': 5,
#   'graph_density': 0.1182181610508281,
#   'modularity': 0.7050053134576393,
#   'average_clustering': 0.3691207617914261,
#   'percent_cross_category_edges': 92.4315619967794},
#  {'average_degree': 12.271844660194175,
#   'average_weighted_degree': 1306.2330097087379,
#   'average_path_length': 2.262707024557396,
#   'network_diameter': 5,
#   'graph_density': 0.12031220255092329,
#   'modularity': 0.6793265407835828,
#   'average_clustering': 0.4365818850624925,
#   'percent_cross_category_edges': 93.82911392405063},
#  {'average_degree': 12.097087378640778,
#   'average_weighted_degree': 1303.7475728155339,
#   'average_path_length': 2.237388159147154,
#   'network_diameter': 5,
#   'graph_density': 0.11859889586902722,
#   'modularity': 0.6751455786078813,
#   'average_clustering': 0.4472204823881095,
#   'percent_cross_category_edges': 93.90048154093098},
#  {'average_degree': 12.79611650485437,
#   'average_weighted_degree': 1380.485436893204,
#   'average_path_length': 2.231677136874167,
#   'network_diameter': 5,
#   'graph_density': 0.12545212259661145,
#   'modularity': 0.6851294272432865,
#   'average_clustering': 0.38084507389903416,
#   'percent_cross_category_edges': 94.08194233687405},
#  {'average_degree': 12.912621359223301,
#   'average_weighted_degree': 1387.8252427184466,
#   'average_path_length': 2.174376546735199,
#   'network_diameter': 4,
#   'graph_density': 0.12659432705120882,
#   'modularity': 0.6466496253696464,
#   'average_clustering': 0.4209664382615769,
#   'percent_cross_category_edges': 96.09022556390977},
#  {'average_degree': 12.54368932038835,
#   'average_weighted_degree': 1378.4271844660195,
#   'average_path_length': 2.2244431753283838,
#   'network_diameter': 4,
#   'graph_density': 0.12297734627831715,
#   'modularity': 0.6587685709773595,
#   'average_clustering': 0.38260234600887183,
#   'percent_cross_category_edges': 93.343653250774},
#  {'average_degree': 12.0,
#   'average_weighted_degree': 1272.4077669902913,
#   'average_path_length': 2.25223681705692,
#   'network_diameter': 4,
#   'graph_density': 0.11764705882352941,
#   'modularity': 0.6886678838155572,
#   'average_clustering': 0.3938032533074417,
#   'percent_cross_category_edges': 94.98381877022653},
#  {'average_degree': 13.009708737864077,
#   'average_weighted_degree': 1390.0776699029127,
#   'average_path_length': 2.1661907481439178,
#   'network_diameter': 4,
#   'graph_density': 0.12754616409670663,
#   'modularity': 0.6083111594583362,
#   'average_clustering': 0.4179770511480405,
#   'percent_cross_category_edges': 94.92537313432837},
#  {'average_degree': 12.388349514563107,
#   'average_weighted_degree': 1334.4466019417475,
#   'average_path_length': 2.192271083190558,
#   'network_diameter': 4,
#   'graph_density': 0.12145440700552065,
#   'modularity': 0.6657358677029218,
#   'average_clustering': 0.3890096240211775,
#   'percent_cross_category_edges': 95.29780564263322},
#  {'average_degree': 12.601941747572816,
#   'average_weighted_degree': 1369.106796116505,
#   'average_path_length': 2.2046449647820294,
#   'network_diameter': 5,
#   'graph_density': 0.12354844850561583,
#   'modularity': 0.6614005563343024,
#   'average_clustering': 0.39078843538383357,
#   'percent_cross_category_edges': 93.22033898305084},
#  {'average_degree': 11.300970873786408,
#   'average_weighted_degree': 886.2912621359224,
#   'average_path_length': 2.271654292785075,
#   'network_diameter': 5,
#   'graph_density': 0.11079383209594518,
#   'modularity': 0.5531632397120515,
#   'average_clustering': 0.3980616390562103,
#   'percent_cross_category_edges': 92.43986254295532},
#  {'average_degree': 10.990291262135923,
#   'average_weighted_degree': 872.0388349514564,
#   'average_path_length': 2.367409099562155,
#   'network_diameter': 6,
#   'graph_density': 0.10774795355035217,
#   'modularity': 0.5745762181727566,
#   'average_clustering': 0.3362459873045915,
#   'percent_cross_category_edges': 92.75618374558304},
#  {'average_degree': 11.572815533980583,
#   'average_weighted_degree': 903.3398058252427,
#   'average_path_length': 2.267846944603084,
#   'network_diameter': 5,
#   'graph_density': 0.11345897582333904,
#   'modularity': 0.5794931649946718,
#   'average_clustering': 0.3561894104764685,
#   'percent_cross_category_edges': 92.11409395973155},
#  {'average_degree': 10.970873786407767,
#   'average_weighted_degree': 847.4368932038835,
#   'average_path_length': 2.320007614696364,
#   'network_diameter': 5,
#   'graph_density': 0.10755758614125262,
#   'modularity': 0.5572806574230866,
#   'average_clustering': 0.34631409503434757,
#   'percent_cross_category_edges': 92.21238938053096},
#  {'average_degree': 11.495145631067961,
#   'average_weighted_degree': 903.3980582524272,
#   'average_path_length': 2.3162002665143726,
#   'network_diameter': 5,
#   'graph_density': 0.1126975061869408,
#   'modularity': 0.5520785470362117,
#   'average_clustering': 0.35451293326050176,
#   'percent_cross_category_edges': 92.0608108108108},
#  {'average_degree': 11.728155339805825,
#   'average_weighted_degree': 904.5631067961165,
#   'average_path_length': 2.284218541785646,
#   'network_diameter': 5,
#   'graph_density': 0.11498191509613555,
#   'modularity': 0.5658820664892921,
#   'average_clustering': 0.31091040605359577,
#   'percent_cross_category_edges': 90.89403973509934},
#  {'average_degree': 10.87378640776699,
#   'average_weighted_degree': 873.5728155339806,
#   'average_path_length': 2.34342280601561,
#   'network_diameter': 5,
#   'graph_density': 0.1066057490957548,
#   'modularity': 0.587783591424047,
#   'average_clustering': 0.3403113385483174,
#   'percent_cross_category_edges': 93.03571428571429},
#  {'average_degree': 11.883495145631068,
#   'average_weighted_degree': 904.7184466019418,
#   'average_path_length': 2.294308014467923,
#   'network_diameter': 5,
#   'graph_density': 0.11650485436893204,
#   'modularity': 0.5583645117554239,
#   'average_clustering': 0.38218179505362787,
#   'percent_cross_category_edges': 91.50326797385621},
#  {'average_degree': 11.611650485436893,
#   'average_weighted_degree': 904.4466019417475,
#   'average_path_length': 2.309727774604988,
#   'network_diameter': 5,
#   'graph_density': 0.11383971064153817,
#   'modularity': 0.5911962935254483,
#   'average_clustering': 0.30457945422596533,
#   'percent_cross_category_edges': 91.80602006688964},
#  {'average_degree': 10.893203883495145,
#   'average_weighted_degree': 863.495145631068,
#   'average_path_length': 2.329906719969541,
#   'network_diameter': 5,
#   'graph_density': 0.10679611650485436,
#   'modularity': 0.5804358838113778,
#   'average_clustering': 0.35339376029440783,
#   'percent_cross_category_edges': 90.37433155080214},
#  {'average_degree': 11.37864077669903,
#   'average_weighted_degree': 896.9126213592233,
#   'average_path_length': 2.303826384922901,
#   'network_diameter': 5,
#   'graph_density': 0.11155530173234342,
#   'modularity': 0.5787920972835691,
#   'average_clustering': 0.3391479335149279,
#   'percent_cross_category_edges': 91.80887372013652},
#  {'average_degree': 11.572815533980583,
#   'average_weighted_degree': 880.9708737864078,
#   'average_path_length': 2.2680373120121837,
#   'network_diameter': 5,
#   'graph_density': 0.11345897582333904,
#   'modularity': 0.6132718824171876,
#   'average_clustering': 0.38514602074039944,
#   'percent_cross_category_edges': 92.28187919463086},
#  {'average_degree': 11.45631067961165,
#   'average_weighted_degree': 887.7669902912621,
#   'average_path_length': 2.333904435560632,
#   'network_diameter': 5,
#   'graph_density': 0.11231677136874167,
#   'modularity': 0.548747724748536,
#   'average_clustering': 0.40243900607959,
#   'percent_cross_category_edges': 92.20338983050847},
#  {'average_degree': 11.533980582524272,
#   'average_weighted_degree': 897.1067961165048,
#   'average_path_length': 2.25642490005711,
#   'network_diameter': 5,
#   'graph_density': 0.11307824100513993,
#   'modularity': 0.5676780539533258,
#   'average_clustering': 0.400213091589659,
#   'percent_cross_category_edges': 92.42424242424242},
#  {'average_degree': 11.359223300970873,
#   'average_weighted_degree': 894.4466019417475,
#   'average_path_length': 2.3234342280601563,
#   'network_diameter': 5,
#   'graph_density': 0.11136493432324386,
#   'modularity': 0.5546085801056682,
#   'average_clustering': 0.3418753763391138,
#   'percent_cross_category_edges': 91.96581196581197},
#  {'average_degree': 12.21359223300971,
#   'average_weighted_degree': 905.0485436893204,
#   'average_path_length': 2.246906529602132,
#   'network_diameter': 4,
#   'graph_density': 0.11974110032362459,
#   'modularity': 0.6243697730822588,
#   'average_clustering': 0.40804808813080734,
#   'percent_cross_category_edges': 93.1637519872814},
#  {'average_degree': 11.300970873786408,
#   'average_weighted_degree': 888.6213592233009,
#   'average_path_length': 2.302113078241005,
#   'network_diameter': 5,
#   'graph_density': 0.11079383209594518,
#   'modularity': 0.5585497379127404,
#   'average_clustering': 0.3970897948391021,
#   'percent_cross_category_edges': 92.9553264604811},
#  {'average_degree': 11.475728155339805,
#   'average_weighted_degree': 899.2621359223301,
#   'average_path_length': 2.309537407195888,
#   'network_diameter': 5,
#   'graph_density': 0.11250713877784123,
#   'modularity': 0.5390477639033034,
#   'average_clustering': 0.32837889003821574,
#   'percent_cross_category_edges': 92.72419627749578},
#  {'average_degree': 11.37864077669903,
#   'average_weighted_degree': 868.4271844660194,
#   'average_path_length': 2.315248429468875,
#   'network_diameter': 4,
#   'graph_density': 0.11155530173234342,
#   'modularity': 0.5723821667846888,
#   'average_clustering': 0.3488196485112876,
#   'percent_cross_category_edges': 92.83276450511946},
#  {'average_degree': 11.339805825242719,
#   'average_weighted_degree': 889.4174757281553,
#   'average_path_length': 2.3337140681515325,
#   'network_diameter': 5,
#   'graph_density': 0.1111745669141443,
#   'modularity': 0.5902395759130463,
#   'average_clustering': 0.32502710367357507,
#   'percent_cross_category_edges': 92.97945205479452},
#  {'average_degree': 11.029126213592233,
#   'average_weighted_degree': 829.2233009708738,
#   'average_path_length': 2.303826384922901,
#   'network_diameter': 5,
#   'graph_density': 0.1081286883685513,
#   'modularity': 0.5803302699880207,
#   'average_clustering': 0.3769276872403876,
#   'percent_cross_category_edges': 92.6056338028169},
#  {'average_degree': 11.805825242718447,
#   'average_weighted_degree': 904.6407766990292,
#   'average_path_length': 2.2503331429659243,
#   'network_diameter': 5,
#   'graph_density': 0.11574338473253379,
#   'modularity': 0.5784594564005174,
#   'average_clustering': 0.38119887778590317,
#   'percent_cross_category_edges': 91.94078947368422},
#  {'average_degree': 11.16504854368932,
#   'average_weighted_degree': 873.2038834951456,
#   'average_path_length': 2.318294308014468,
#   'network_diameter': 5,
#   'graph_density': 0.10946126023224824,
#   'modularity': 0.5986126384555335,
#   'average_clustering': 0.32703736530310884,
#   'percent_cross_category_edges': 93.73913043478261},
#  {'average_degree': 10.699029126213592,
#   'average_weighted_degree': 812.7184466019418,
#   'average_path_length': 2.2830763373310488,
#   'network_diameter': 4,
#   'graph_density': 0.10489244241385874,
#   'modularity': 0.5473883647632923,
#   'average_clustering': 0.3896559019097635,
#   'percent_cross_category_edges': 92.37749546279493},
#  {'average_degree': 11.611650485436893,
#   'average_weighted_degree': 904.4466019417475,
#   'average_path_length': 2.272606129830573,
#   'network_diameter': 4,
#   'graph_density': 0.11383971064153817,
#   'modularity': 0.5654775556725857,
#   'average_clustering': 0.34133552134384476,
#   'percent_cross_category_edges': 92.3076923076923},
#  {'average_degree': 10.932038834951456,
#   'average_weighted_degree': 870.9514563106796,
#   'average_path_length': 2.3093470397867883,
#   'network_diameter': 4,
#   'graph_density': 0.10717685132305349,
#   'modularity': 0.6135747703817336,
#   'average_clustering': 0.3616019836072433,
#   'percent_cross_category_edges': 92.36234458259325},
#  {'average_degree': 11.572815533980583,
#   'average_weighted_degree': 904.3300970873786,
#   'average_path_length': 2.2937369122406244,
#   'network_diameter': 5,
#   'graph_density': 0.11345897582333904,
#   'modularity': 0.5335934766412052,
#   'average_clustering': 0.36318825731155097,
#   'percent_cross_category_edges': 92.28187919463086},
#  {'average_degree': 11.37864077669903,
#   'average_weighted_degree': 900.4466019417475,
#   'average_path_length': 2.324005330287455,
#   'network_diameter': 5,
#   'graph_density': 0.11155530173234342,
#   'modularity': 0.5828279837593393,
#   'average_clustering': 0.3814452749396275,
#   'percent_cross_category_edges': 92.15017064846417},
#  {'average_degree': 11.41747572815534,
#   'average_weighted_degree': 894.6407766990292,
#   'average_path_length': 2.372929754426042,
#   'network_diameter': 5,
#   'graph_density': 0.11193603655054254,
#   'modularity': 0.5708677751016877,
#   'average_clustering': 0.3276282283835648,
#   'percent_cross_category_edges': 90.64625850340136},
#  {'average_degree': 10.58252427184466,
#   'average_weighted_degree': 881.2815533980582,
#   'average_path_length': 2.3841614315629163,
#   'network_diameter': 5,
#   'graph_density': 0.10375023795926137,
#   'modularity': 0.5672344729589497,
#   'average_clustering': 0.3077124627466542,
#   'percent_cross_category_edges': 90.45871559633028},
#  {'average_degree': 11.669902912621358,
#   'average_weighted_degree': 904.504854368932,
#   'average_path_length': 2.2849800114220447,
#   'network_diameter': 5,
#   'graph_density': 0.11441081286883685,
#   'modularity': 0.5740970365456488,
#   'average_clustering': 0.39865195323355485,
#   'percent_cross_category_edges': 92.84525790349417},
#  {'average_degree': 10.815533980582524,
#   'average_weighted_degree': 830.7961165048544,
#   'average_path_length': 2.4062440510184655,
#   'network_diameter': 6,
#   'graph_density': 0.10603464686845612,
#   'modularity': 0.6205514404741582,
#   'average_clustering': 0.3254373496948367,
#   'percent_cross_category_edges': 93.17773788150808},
#  {'average_degree': 11.281553398058252,
#   'average_weighted_degree': 896.9320388349514,
#   'average_path_length': 2.359032933561774,
#   'network_diameter': 6,
#   'graph_density': 0.1106034646868456,
#   'modularity': 0.5927883900411638,
#   'average_clustering': 0.38375865156050093,
#   'percent_cross_category_edges': 93.11531841652324},
#  {'average_degree': 10.310679611650485,
#   'average_weighted_degree': 765.5922330097087,
#   'average_path_length': 2.3540833809251858,
#   'network_diameter': 5,
#   'graph_density': 0.1010850942318675,
#   'modularity': 0.6206048174885441,
#   'average_clustering': 0.31445668030158713,
#   'percent_cross_category_edges': 90.96045197740112},
#  {'average_degree': 11.650485436893204,
#   'average_weighted_degree': 904.4854368932039,
#   'average_path_length': 2.303445650104702,
#   'network_diameter': 5,
#   'graph_density': 0.1142204454597373,
#   'modularity': 0.6024875142258094,
#   'average_clustering': 0.37582395552985337,
#   'percent_cross_category_edges': 92.33333333333333},
#  {'average_degree': 11.611650485436893,
#   'average_weighted_degree': 904.4466019417475,
#   'average_path_length': 2.2389110984199503,
#   'network_diameter': 4,
#   'graph_density': 0.11383971064153817,
#   'modularity': 0.573524280608318,
#   'average_clustering': 0.38361803333312533,
#   'percent_cross_category_edges': 92.14046822742475},
#  {'average_degree': 11.592233009708737,
#   'average_weighted_degree': 903.7281553398059,
#   'average_path_length': 2.2588996763754046,
#   'network_diameter': 4,
#   'graph_density': 0.11364934323243861,
#   'modularity': 0.5716921172967714,
#   'average_clustering': 0.3605525973789068,
#   'percent_cross_category_edges': 92.79731993299832},
#  {'average_degree': 11.145631067961165,
#   'average_weighted_degree': 889.8446601941747,
#   'average_path_length': 2.3002094041500096,
#   'network_diameter': 5,
#   'graph_density': 0.10927089282314868,
#   'modularity': 0.5231268584191177,
#   'average_clustering': 0.3612080261512665,
#   'percent_cross_category_edges': 94.25087108013938},
#  {'average_degree': 11.41747572815534,
#   'average_weighted_degree': 896.1553398058253,
#   'average_path_length': 2.2668951075575863,
#   'network_diameter': 5,
#   'graph_density': 0.11193603655054254,
#   'modularity': 0.5557837158274567,
#   'average_clustering': 0.36943263412630756,
#   'percent_cross_category_edges': 92.00680272108843},
#  {'average_degree': 10.932038834951456,
#   'average_weighted_degree': 866.0776699029126,
#   'average_path_length': 2.2927850751951264,
#   'network_diameter': 5,
#   'graph_density': 0.10717685132305349,
#   'modularity': 0.5860801766424063,
#   'average_clustering': 0.3951229142933991,
#   'percent_cross_category_edges': 92.53996447602132},
#  {'average_degree': 11.45631067961165,
#   'average_weighted_degree': 873.1844660194175,
#   'average_path_length': 2.304778221968399,
#   'network_diameter': 5,
#   'graph_density': 0.11231677136874167,
#   'modularity': 0.5311647494823365,
#   'average_clustering': 0.31068784795414356,
#   'percent_cross_category_edges': 92.37288135593221},
#  {'average_degree': 11.41747572815534,
#   'average_weighted_degree': 893.3786407766991,
#   'average_path_length': 2.271654292785075,
#   'network_diameter': 4,
#   'graph_density': 0.11193603655054254,
#   'modularity': 0.5757808635665014,
#   'average_clustering': 0.3235721311425862,
#   'percent_cross_category_edges': 93.19727891156462},
#  {'average_degree': 11.029126213592233,
#   'average_weighted_degree': 891.7281553398059,
#   'average_path_length': 2.3807348181991244,
#   'network_diameter': 5,
#   'graph_density': 0.1081286883685513,
#   'modularity': 0.5416286974978963,
#   'average_clustering': 0.31669468826113223,
#   'percent_cross_category_edges': 92.0774647887324},
#  {'average_degree': 11.320388349514563,
#   'average_weighted_degree': 878.3689320388349,
#   'average_path_length': 2.315629164287074,
#   'network_diameter': 5,
#   'graph_density': 0.11098419950504473,
#   'modularity': 0.589908368257644,
#   'average_clustering': 0.35670385911097974,
#   'percent_cross_category_edges': 94.33962264150944},
#  {'average_degree': 11.631067961165048,
#   'average_weighted_degree': 904.4660194174758,
#   'average_path_length': 2.2406244051018467,
#   'network_diameter': 4,
#   'graph_density': 0.11403007805063774,
#   'modularity': 0.5981063823030724,
#   'average_clustering': 0.337817196616534,
#   'percent_cross_category_edges': 92.82136894824707},
#  {'average_degree': 11.514563106796116,
#   'average_weighted_degree': 900.6796116504854,
#   'average_path_length': 2.3053493241956975,
#   'network_diameter': 5,
#   'graph_density': 0.11288787359604036,
#   'modularity': 0.591518963104226,
#   'average_clustering': 0.39273761531992324,
#   'percent_cross_category_edges': 93.25463743676222},
#  {'average_degree': 11.825242718446601,
#   'average_weighted_degree': 904.6601941747573,
#   'average_path_length': 2.2427184466019416,
#   'network_diameter': 5,
#   'graph_density': 0.11593375214163336,
#   'modularity': 0.5947885248053317,
#   'average_clustering': 0.385325298038727,
#   'percent_cross_category_edges': 92.9392446633826},
#  {'average_degree': 11.844660194174757,
#   'average_weighted_degree': 904.6796116504854,
#   'average_path_length': 2.260041880830002,
#   'network_diameter': 5,
#   'graph_density': 0.11612411955073292,
#   'modularity': 0.5359382782961716,
#   'average_clustering': 0.39326754466881486,
#   'percent_cross_category_edges': 93.11475409836065},
#  {'average_degree': 10.660194174757281,
#   'average_weighted_degree': 836.2718446601941,
#   'average_path_length': 2.3207690843327624,
#   'network_diameter': 5,
#   'graph_density': 0.10451170759565963,
#   'modularity': 0.5763085558219531,
#   'average_clustering': 0.3504807835199696,
#   'percent_cross_category_edges': 92.71402550091075},
#  {'average_degree': 10.737864077669903,
#   'average_weighted_degree': 839.9805825242719,
#   'average_path_length': 2.3405672948791167,
#   'network_diameter': 5,
#   'graph_density': 0.10527317723205787,
#   'modularity': 0.6100317582885362,
#   'average_clustering': 0.3826707466588047,
#   'percent_cross_category_edges': 91.86256781193491}]

# %%
# Print results
for metric, stats in results.items():
    print(f"{metric.capitalize().replace('_', ' ')}:")
    print(f"  Female Original Value: {f_original_metrics[metric]:.4f}")
    print(f"  Male Original Value: {m_original_metrics[metric]:.4f}")
    print(f"  Random Average: {statistics.mean(rd_metric[metric] for rd_metric in random_metrics):.4f}")
    print(f"  Random Standard Deviation: {statistics.stdev(rd_metric[metric] for rd_metric in random_metrics):.4f}")
    print(f"  T-Statistic: {stats['t_stat']:.4f}" if stats['t_stat'] is not None else "  T-Statistic: N/A")
    print(f"  P-Value: {stats['p_value']:.4f}" if stats['p_value'] is not None else "  P-Value: N/A")
    if stats["p_value"] is not None:
        if stats["p_value"] < 0.05:
            print("  Significant difference detected.")
        else:
            print("  No significant difference detected.")
    print("-" * 50)
# Out:
# Average degree:
#   Female Original Value: 13.1262
#   Male Original Value: 11.6117
#   Random Average: 11.9309
#   Random Standard Deviation: 0.7361
#   T-Statistic: -75.2593
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Average weighted degree:
#   Female Original Value: 1391.3592
#   Male Original Value: 904.4466
#   Random Average: 1105.9625
#   Random Standard Deviation: 228.3515
#   T-Statistic: -79.4686
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Average path length:
#   Female Original Value: 2.1611
#   Male Original Value: 2.3503
#   Random Average: 2.2598
#   Random Standard Deviation: 0.0598
#   T-Statistic: 141.9073
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Network diameter:
#   Female Original Value: 4.0000
#   Male Original Value: 6.0000
#   Random Average: 4.6600
#   Random Standard Deviation: 0.5545
#   T-Statistic: 167.2302
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Graph density:
#   Female Original Value: 0.1287
#   Male Original Value: 0.1138
#   Random Average: 0.1170
#   Random Standard Deviation: 0.0072
#   T-Statistic: -75.2593
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Modularity:
#   Female Original Value: 0.1312
#   Male Original Value: 0.2390
#   Random Average: 0.6230
#   Random Standard Deviation: 0.0566
#   T-Statistic: 170.8559
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Average clustering:
#   Female Original Value: 0.4814
#   Male Original Value: 0.3980
#   Random Average: 0.3798
#   Random Standard Deviation: 0.0370
#   T-Statistic: -91.8596
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------
# Percent cross category edges:
#   Female Original Value: 89.3491
#   Male Original Value: 88.1271
#   Random Average: 93.2032
#   Random Standard Deviation: 1.1764
#   T-Statistic: -21.2352
#   P-Value: 0.0000
#   Significant difference detected.
# --------------------------------------------------

# %% [markdown]
# # Save out clusters from Louvain cluster

# %%
random.seed(123)

# %%
# Modularity (using Louvain method)
def get_louvain_clusters(graph, node_categories):
    partition = community_louvain.best_partition(graph)
    communities = {}
    for node, comm_id in partition.items():
        communities.setdefault(comm_id, set()).add(node)
    
    # Convert the dictionary into a list of tuples (node, cluster)
    data = [(node, cluster) for cluster, nodes in communities.items() for node in nodes]

    # Create a pandas DataFrame
    df = pd.DataFrame(data, columns=["Node", "Cluster"])
    df['disease_category'] = df['Node'].map(node_categories)
    return df

# %%
clusters_f = get_louvain_clusters(G_f, node_categories)
clusters_m = get_louvain_clusters(G_m, node_categories)

# %%
clusters_f.to_csv("/Users/vsriram/Desktop/G_f_clusters.csv", index=False)
clusters_m.to_csv("/Users/vsriram/Desktop/G_m_clusters.csv", index=False)
